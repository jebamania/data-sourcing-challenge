# %% [markdown]
# ### Import Required Libraries and Set Up Environment Variables

# %%
import sys
print(sys.path)
# Out:
# ['c:\\Repos\\data-sourcing-challenge', 'c:\\Users\\Jake\\anaconda3\\envs\\dev\\python310.zip', 'c:\\Users\\Jake\\anaconda3\\envs\\dev\\DLLs', 'c:\\Users\\Jake\\anaconda3\\envs\\dev\\lib', 'c:\\Users\\Jake\\anaconda3\\envs\\dev', '', 'c:\\Users\\Jake\\anaconda3\\envs\\dev\\lib\\site-packages', 'c:\\Users\\Jake\\anaconda3\\envs\\dev\\lib\\site-packages\\win32', 'c:\\Users\\Jake\\anaconda3\\envs\\dev\\lib\\site-packages\\win32\\lib', 'c:\\Users\\Jake\\anaconda3\\envs\\dev\\lib\\site-packages\\Pythonwin']

# %%
# Dependencies
import requests
import time
from dotenv import load_dotenv
import os
import pandas as pd
import json
import numpy as np

# %%
# Set environment variables from the .env in the local environment
load_dotenv()

nyt_api_key = os.getenv("NYT_API_KEY")
tmdb_api_key = os.getenv("TMDB_API_KEY")

# %% [markdown]
# ### Access the New York Times API

# %%
# Set the base URL
uri = f"https://api.nytimes.com/svc/search/v2/articlesearch.json?api-key={nyt_api_key}&"

# Filter for movie reviews with "love" in the headline
# section_name should be "Movies"
# type_of_material should be "Review"
filter_query = 'section_name:("Movies") AND type_of_material:("Review") AND headline:("love")'

# Use a sort filter, sort by newest
sort = "newest"

# Select the following fields to return:
# headline, web_url, snippet, source, keywords, pub_date, byline, word_count
field_list = "headline,web_url,snippet,source,keywords,pub_date,byline,word_count"

# Search for reviews published between a begin and end date
begin_date = "20130101"
end_date = "20230531"

# Build URL
url = uri + f'fq={filter_query}&sort={sort}&fl={field_list}&begindate={begin_date}&end_date={end_date}'

url
# Out:
# 'https://api.nytimes.com/svc/search/v2/articlesearch.json?api-key=b7yQGXkHbCIfiakav77zRdZ5Nu1QjgqU&fq=section_name:("Movies") AND type_of_material:("Review") AND headline:("love")&sort=newest&fl=headline,web_url,snippet,source,keywords,pub_date,byline,word_count&begindate=20130101&end_date=20230531'

# %%
# Create an empty list to store the reviews
reviews_list = []
page_nbr = 1

# loop through pages 0-19
while page_nbr < 20:

    # create query with a page number
    # API results show 10 articles at a time
    # Make a "GET" request and retrieve the JSON
    response = requests.get(url + f'&page={page_nbr}')
    
    # Try and save the reviews to the reviews_list
    # add the reviews from the response to the stored reviews_list variable
    data = response.json()
    reviews_list.extend(data['response']['docs'])

    # Print the page that was just retrieved
    print(f'Checked page {page_nbr}')

    # Print the page number that had no results then break from the loop
    if len(data['response']['docs']) == 0:
        print(f'{page_nbr} is empty.')
        break;
    
    # increment page
    page_nbr += 1
    
    # Add a twelve second interval between queries to stay within API query limits
    time.sleep(12)
# Out:
# Checked page 1
# Checked page 2
# Checked page 3
# Checked page 4
# Checked page 5
# Checked page 6
# Checked page 7
# Checked page 8
# Checked page 9
# Checked page 10
# Checked page 11
# Checked page 12
# Checked page 13
# Checked page 14
# Checked page 15
# Checked page 16
# Checked page 17
# Checked page 18
# Checked page 19

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data
print(json.dumps(reviews_list,indent=4))
# Out:
# [
#     {
#         "web_url": "https://www.nytimes.com/2023/01/31/movies/pamela-a-love-story-review.html",
#         "snippet": "This documentary from Ryan White rewinds, to powerful effect, on Pamela Anderson\u2019s life and fame.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018Pamela, a Love Story\u2019 Review: A Frank Look Back",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "Pamela, a Love Story",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Documentary Films and Programs",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Anderson, Pamela (1967- )",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "White, Ryan (Filmmaker)",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Pamela, a Love Story (Movie)",
#                 "rank": 4,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-01-31T12:00:05+0000",
#         "byline": {
#             "original": "By Glenn Kenny",
#             "person": [
#                 {
#                     "firstname": "Glenn",
#                     "middlename": null,
#                     "lastname": "Kenny",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 295
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/01/19/movies/in-from-the-side-review.html",
#         "snippet": "In Matt Carter\u2019s gay rugby film, sports and romance smash together like two players from opposing teams.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018In From the Side\u2019 Review: Love and Rugby Play a Losing Game",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "In From the Side",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "In From the Side (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Carter, Matt (Filmmaker)",
#                 "rank": 3,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-01-19T17:50:16+0000",
#         "byline": {
#             "original": "By Kyle Turner",
#             "person": [
#                 {
#                     "firstname": "Kyle",
#                     "middlename": null,
#                     "lastname": "Turner",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 281
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/01/19/movies/after-love-review.html",
#         "snippet": "In this intelligent melodrama by the director Aleem Khan, a British woman discovers her husband has been leading a double life.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018After Love\u2019 Review: The Other Woman",
#             "kicker": "Critic\u2019s Pick",
#             "content_kicker": null,
#             "print_headline": "After Love",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "After Love (2020) (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Khan, Aleem",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Scanlan, Joanna (1961- )",
#                 "rank": 4,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-01-19T12:00:06+0000",
#         "byline": {
#             "original": "By Beatrice Loayza",
#             "person": [
#                 {
#                     "firstname": "Beatrice",
#                     "middlename": null,
#                     "lastname": "Loayza",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 359
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/01/05/movies/alcarras-review.html",
#         "snippet": "In this naturalistic drama from Spain, a family confronts the impending loss of its generations-old farm.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018Alcarr\u00e0s\u2019 Review: Labor of Love",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "Alcarr\u00e0s",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Simon, Carla",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Alcarras (Movie)",
#                 "rank": 3,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-01-05T12:00:03+0000",
#         "byline": {
#             "original": "By Devika Girish",
#             "person": [
#                 {
#                     "firstname": "Devika",
#                     "middlename": null,
#                     "lastname": "Girish",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 306
#     },
#     {
#         "web_url": "https://www.nytimes.com/2022/12/15/movies/nelly-and-nadine-review.html",
#         "snippet": "A family archive provides intimate records of a love affair that began between two women imprisoned in the Ravensbr\u00fcck concentration camp.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018Nelly & Nadine\u2019 Review: An Unlikely Love, an Unlikely Record",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "Nelly &amp; Nadine",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Documentary Films and Programs",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Gertten, Magnus",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Nelly & Nadine (Movie)",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Content Type: Personal Profile",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Holocaust and the Nazi Era",
#                 "rank": 5,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "World War II (1939-45)",
#                 "rank": 6,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Women and Girls",
#                 "rank": 7,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Homosexuality and Bisexuality",
#                 "rank": 8,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2022-12-15T12:00:04+0000",
#         "byline": {
#             "original": "By Teo Bugbee",
#             "person": [
#                 {
#                     "firstname": "Teo",
#                     "middlename": null,
#                     "lastname": "Bugbee",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 308
#     },
#     {
#         "web_url": "https://www.nytimes.com/2022/12/01/movies/lady-chatterleys-lover-review.html",
#         "snippet": "The new Netflix adaptation of D.H. Lawrence\u2019s once-controversial novel is both steamy and decorous.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018Lady Chatterley\u2019s Lover\u2019 Review: When Connie Met Ollie",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "A Love Whose Name Is Often Spoken",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Lady Chatterley's Lover (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Corrin, Emma (1995- )",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "De Clermont-Tonnerre, Laure",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Lawrence, D H",
#                 "rank": 5,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2022-12-01T16:40:55+0000",
#         "byline": {
#             "original": "By A.O. Scott",
#             "person": [
#                 {
#                     "firstname": "A.",
#                     "middlename": "O.",
#                     "lastname": "Scott",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 768
#     },
#     {
#         "web_url": "https://www.nytimes.com/2022/11/23/movies/sound-of-christmas-review.html",
#         "snippet": "A young singer gets more than she bargained for when she accepts a job as a nanny for a billionaire\u2019s children.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018The Sound of Christmas\u2019 Review: A Gospel Singer Finds Love",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "The Sound  Of Christmas",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Ne-Yo",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "The Sound of Christmas (Movie)",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Mattison, Booker T",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "McNeill, Serayah",
#                 "rank": 5,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2022-11-23T15:00:09+0000",
#         "byline": {
#             "original": "By Concepci\u00f3n de Le\u00f3n",
#             "person": [
#                 {
#                     "firstname": "Concepci\u00f3n",
#                     "middlename": null,
#                     "lastname": "de Le\u00f3n",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 277
#     },
#     {
#         "web_url": "https://www.nytimes.com/2022/11/17/movies/the-inspection-review-boot-camp-a-love-story.html",
#         "snippet": "Elegance Bratton\u2019s autobiographical first feature is a lyrical, wrenching look at a young Marine\u2019s journey through basic training.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018The Inspection\u2019 Review: Boot Camp, a Love Story",
#             "kicker": "critic\u2019s pick",
#             "content_kicker": null,
#             "print_headline": "A Few Good Men, Some With Secrets",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "The Inspection (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Bratton, Elegance",
#                 "rank": 3,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2022-11-17T12:00:07+0000",
#         "byline": {
#             "original": "By A.O. Scott",
#             "person": [
#                 {
#                     "firstname": "A.",
#                     "middlename": "O.",
#                     "lastname": "Scott",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 836
#     },
#     {
#         "web_url": "https://www.nytimes.com/2022/11/17/movies/bones-and-all-review.html",
#         "snippet": "Luca Guadagnino\u2019s latest stars Timoth\u00e9e Chalamet and Taylor Russell as young cannibals on the run.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018Bones and All\u2019 Review: You Eat What You Are",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "It\u2019s Eat, Prey, Love on a Journey of Self-Discovery",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Bones and All (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Guadagnino, Luca",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Chalamet, Timothee (1995- )",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Russell, Taylor (1994- )",
#                 "rank": 5,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2022-11-17T12:00:06+0000",
#         "byline": {
#             "original": "By A.O. Scott",
#             "person": [
#                 {
#                     "firstname": "A.",
#                     "middlename": "O.",
#                     "lastname": "Scott",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 710
#     },
#     {
#         "web_url": "https://www.nytimes.com/2022/10/20/movies/my-policeman-review.html",
#         "snippet": "A schoolteacher, her police officer husband and his lover deny each other romantic satisfaction in this dismal melodrama.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018My Policeman\u2019 Review: Two Love Affairs, Equally Tragic",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "My Policeman",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "My Policeman (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Grandage, Michael",
#                 "rank": 3,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2022-10-20T16:52:51+0000",
#         "byline": {
#             "original": "By Teo Bugbee",
#             "person": [
#                 {
#                     "firstname": "Teo",
#                     "middlename": null,
#                     "lastname": "Bugbee",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 303
#     },
#     {
#         "web_url": "https://www.nytimes.com/2022/09/08/movies/about-fate-review.html",
#         "snippet": "Thomas Mann\u2019s beguiling performance drives this Emma Roberts vehicle, but the romantic comedy creaks under the weight of its coincidences.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018About Fate\u2019 Review: Love the One You\u2019re With?",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "About Fate",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "About Fate (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Vaysberg, Marius",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Mann, Thomas (1991- )",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Roberts, Emma (1991- )",
#                 "rank": 5,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2022-09-09T01:00:03+0000",
#         "byline": {
#             "original": "By Lisa Kennedy",
#             "person": [
#                 {
#                     "firstname": "Lisa",
#                     "middlename": null,
#                     "lastname": "Kennedy",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 289
#     },
#     {
#         "web_url": "https://www.nytimes.com/2022/09/01/movies/waiting-for-bojangles-review-endless-love.html",
#         "snippet": "Set in Paris in the 1960s, the film tells the story of two irrepressible lovers, and their young son, whose tale turns tragic.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018Waiting for Bojangles\u2019 Review: Endless Love",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "Waiting for Bojangles",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Bourdeaut, Olivier",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Waiting for Bojangles (Movie)",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Roinsard, Regis",
#                 "rank": 4,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2022-09-01T11:00:06+0000",
#         "byline": {
#             "original": "By Calum Marsh",
#             "person": [
#                 {
#                     "firstname": "Calum",
#                     "middlename": null,
#                     "lastname": "Marsh",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 267
#     },
#     {
#         "web_url": "https://www.nytimes.com/2022/08/04/movies/i-love-my-dad-review.html",
#         "snippet": "This comedy is a daddy-issues movie with a queasy premise truly made for these times.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018I Love My Dad\u2019 Review: A Father Catfishes His Son",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "A Father Catfishes His Son. We Just Wait for the Ick.",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Oswalt, Patton",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "I Love My Dad (Movie)",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Morosini, James",
#                 "rank": 4,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2022-08-04T11:00:05+0000",
#         "byline": {
#             "original": "By Glenn Kenny",
#             "person": [
#                 {
#                     "firstname": "Glenn",
#                     "middlename": null,
#                     "lastname": "Kenny",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 418
#     },
#     {
#         "web_url": "https://www.nytimes.com/2022/07/28/movies/a-love-song-review.html",
#         "snippet": "Two former childhood friends rekindle their connection in this sweetly hopeful story of romantic longing.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018A Love Song\u2019 Review: When Moving Forward Means Looking Back",
#             "kicker": "Critic\u2019s Pick",
#             "content_kicker": null,
#             "print_headline": "The Romantic Ache That Never Truly Dies",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "A Love Song (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Walker-Silverman, Max",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Dickey, Dale (Actor)",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Studi, Wes",
#                 "rank": 5,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2022-07-28T11:00:06+0000",
#         "byline": {
#             "original": "By Jeannette Catsoulis",
#             "person": [
#                 {
#                     "firstname": "Jeannette",
#                     "middlename": null,
#                     "lastname": "Catsoulis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 395
#     },
#     {
#         "web_url": "https://www.nytimes.com/2022/07/21/movies/alone-together-review.html",
#         "snippet": "Katie Holmes writes, directs and stars in this minor-key rom-com set in 2020.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018Alone Together\u2019 Review: Finding Love in a Pandemic Retreat",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "Alone Together",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Holmes, Katie",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Alone Together (Movie)",
#                 "rank": 3,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2022-07-21T15:37:18+0000",
#         "byline": {
#             "original": "By Teo Bugbee",
#             "person": [
#                 {
#                     "firstname": "Teo",
#                     "middlename": null,
#                     "lastname": "Bugbee",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 254
#     },
#     {
#         "web_url": "https://www.nytimes.com/2022/07/21/movies/art-of-love-review.html",
#         "snippet": "A disillusioned college professor develops a relationship with a young Chinese woman, in a familiar and worn-out narrative.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018Art of Love\u2019 Review: An Erotic Male Fantasy in Puerto Rico",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "Art of Love",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Art of Love (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Kaplan, Betty (Film Director)",
#                 "rank": 3,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2022-07-21T13:21:43+0000",
#         "byline": {
#             "original": "By Concepci\u00f3n de Le\u00f3n",
#             "person": [
#                 {
#                     "firstname": "Concepci\u00f3n",
#                     "middlename": null,
#                     "lastname": "de Le\u00f3n",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 354
#     },
#     {
#         "web_url": "https://www.nytimes.com/2022/07/21/movies/the-wheel-review.html",
#         "snippet": "In this marriage drama, a young couple heads to the countryside to break out of a toxic cycle.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018The Wheel\u2019 Review: Songs of Love and Hate",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "The Wheel",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "The Wheel (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Pink, Steve",
#                 "rank": 3,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2022-07-21T11:00:08+0000",
#         "byline": {
#             "original": "By Nicolas Rapold",
#             "person": [
#                 {
#                     "firstname": "Nicolas",
#                     "middlename": null,
#                     "lastname": "Rapold",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 287
#     },
#     {
#         "web_url": "https://www.nytimes.com/2022/07/07/movies/thor-love-and-thunder-review.html",
#         "snippet": "The director Taika Waititi injects antic silliness, once again, into this Marvel franchise starring Chris Hemsworth, who swings a mighty hammer and flexes mightier muscles.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018Thor: Love and Thunder\u2019 Review: A God\u2019s Comic Twilight",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "He\u2019s Still a Norse God, But Also a Big Old Goof",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "organizations",
#                 "value": "Marvel Studios",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Bale, Christian",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Crowe, Russell",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Hemsworth, Chris",
#                 "rank": 5,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Waititi, Taika",
#                 "rank": 6,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Thompson, Tessa",
#                 "rank": 7,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Portman, Natalie",
#                 "rank": 8,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2022-07-07T18:26:10+0000",
#         "byline": {
#             "original": "By Manohla Dargis",
#             "person": [
#                 {
#                     "firstname": "Manohla",
#                     "middlename": null,
#                     "lastname": "Dargis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 942
#     },
#     {
#         "web_url": "https://www.nytimes.com/2022/07/07/movies/both-sides-of-the-blade-review.html",
#         "snippet": "In the latest film from Claire Denis, Juliette Binoche plays a Parisian radio journalist in a romantic quandary.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018Both Sides of the Blade\u2019 Review: Who Do You Love?",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "A Bliss Doomed To Be Doused",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Denis, Claire",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Binoche, Juliette",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Lindon, Vincent",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Both Sides of the Blade (Movie)",
#                 "rank": 5,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2022-07-07T11:00:07+0000",
#         "byline": {
#             "original": "By A.O. Scott",
#             "person": [
#                 {
#                     "firstname": "A.",
#                     "middlename": "O.",
#                     "lastname": "Scott",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 649
#     },
#     {
#         "web_url": "https://www.nytimes.com/2022/07/06/movies/fire-of-love-review.html",
#         "snippet": "Sara Dosa\u2019s new documentary chronicles the lives and deaths of the French scientists Katia and Maurice Krafft.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018Fire of Love\u2019 Review: A Volcanic Romance",
#             "kicker": "critic\u2019s pick",
#             "content_kicker": null,
#             "print_headline": "A Volcanic Romance Across Continents",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Documentary Films and Programs",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Volcanoes",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Fire of Love (Movie)",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Content Type: Personal Profile",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Deaths (Fatalities)",
#                 "rank": 5,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Dosa, Sara",
#                 "rank": 6,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Krafft, Maurice (1946-91)",
#                 "rank": 7,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Krafft, Katia (1942-91)",
#                 "rank": 8,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2022-07-06T11:00:06+0000",
#         "byline": {
#             "original": "By A.O. Scott",
#             "person": [
#                 {
#                     "firstname": "A.",
#                     "middlename": "O.",
#                     "lastname": "Scott",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 609
#     },
#     {
#         "web_url": "https://www.nytimes.com/2022/06/22/movies/love-gelato-review.html",
#         "snippet": "A mother\u2019s final wish leads her daughter to retrace her Roman holiday in this lighthearted coming-of-age story.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018Love & Gelato\u2019 Review: A Young Girl, Transfigured by Italy",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "Love &amp; Gelato",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Love & Gelato (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Camp, Brandon (1971- )",
#                 "rank": 3,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2022-06-23T03:06:01+0000",
#         "byline": {
#             "original": "By Teo Bugbee",
#             "person": [
#                 {
#                     "firstname": "Teo",
#                     "middlename": null,
#                     "lastname": "Bugbee",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 288
#     },
#     {
#         "web_url": "https://www.nytimes.com/2022/06/16/movies/stay-prayed-up-review.html",
#         "snippet": "A new documentary about the gospel ensemble the Branchettes and its guiding light, Lena Mae Perry, is a plain-spoken tribute.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018Stay Prayed Up\u2019 Review: Spreading the Gospel of Love",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "Stay Prayed Up",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Documentary Films and Programs",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Gospel Music",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Stay Prayed Up (Movie)",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Content Type: Personal Profile",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Perry, Lena Mae",
#                 "rank": 5,
#                 "major": "N"
#             },
#             {
#                 "name": "organizations",
#                 "value": "Branchettes (Music Group)",
#                 "rank": 6,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Anderson, DL (Filmmaker)",
#                 "rank": 7,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Durning, Matthew",
#                 "rank": 8,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2022-06-16T11:00:08+0000",
#         "byline": {
#             "original": "By Glenn Kenny",
#             "person": [
#                 {
#                     "firstname": "Glenn",
#                     "middlename": null,
#                     "lastname": "Kenny",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 330
#     },
#     {
#         "web_url": "https://www.nytimes.com/2022/06/02/movies/benediction-review.html",
#         "snippet": "Terence Davies\u2019s latest film is a biography of Siegfried Sassoon, whose writing about World War I changed British literature.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018Benediction\u2019 Review: A Poet\u2019s Life, in Love and War",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "A Poet\u2019s Life, In Love and War",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Davies, Terence",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Benediction (Movie)",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Lowden, Jack (1990- )",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Poetry and Poets",
#                 "rank": 5,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Sassoon, Siegfried",
#                 "rank": 6,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2022-06-02T11:00:06+0000",
#         "byline": {
#             "original": "By A.O. Scott",
#             "person": [
#                 {
#                     "firstname": "A.",
#                     "middlename": "O.",
#                     "lastname": "Scott",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 883
#     },
#     {
#         "web_url": "https://www.nytimes.com/2022/05/26/movies/dinner-in-america-review.html",
#         "snippet": "A rage-fueled rock singer on the run from the police meets and falls in love with a gullible young woman eager to escape her circumstances.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018Dinner in America\u2019 Review: A Punk-Rock Love Story",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "Dinner in America",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Rehmeier, Adam",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Dinner in America (Book)",
#                 "rank": 3,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2022-05-26T11:00:04+0000",
#         "byline": {
#             "original": "By Concepci\u00f3n de Le\u00f3n",
#             "person": [
#                 {
#                     "firstname": "Concepci\u00f3n",
#                     "middlename": null,
#                     "lastname": "de Le\u00f3n",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 254
#     },
#     {
#         "web_url": "https://www.nytimes.com/2022/05/03/movies/in-a-new-york-minute-review.html",
#         "snippet": "This drama from Ximan Li teases time in telling the stories of three Chinese women living in a city that tempts promise but delivers frustration.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018In a New York Minute\u2019 Review: Love or Freedom?",
# ...
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "The Happiest Day in the Life of Olli Maki (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Kuosmanen, Juho",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Lahti, Jarkko",
#                 "rank": 4,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2017-04-20T20:45:54+0000",
#         "byline": {
#             "original": "By Manohla Dargis",
#             "person": [
#                 {
#                     "firstname": "Manohla",
#                     "middlename": null,
#                     "lastname": "Dargis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 824
#     },
#     {
#         "web_url": "https://www.nytimes.com/2017/04/20/movies/the-promise-review-oscar-isaac.html",
#         "snippet": "Oscar Isaac, Christian Bale and Charlotte Le Bon star in this wartime romance with a heavy subject (genocide) but a corny plot.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Review: \u2018The Promise\u2019 Finds a Love Triangle in Constantinople",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "A Love Triangle, Near the Front Lines",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "The Promise (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "George, Terry",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Bale, Christian",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Isaac, Oscar",
#                 "rank": 5,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Le Bon, Charlotte",
#                 "rank": 6,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2017-04-20T16:49:46+0000",
#         "byline": {
#             "original": "By Jeannette Catsoulis",
#             "person": [
#                 {
#                     "firstname": "Jeannette",
#                     "middlename": null,
#                     "lastname": "Catsoulis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 455
#     },
#     {
#         "web_url": "https://www.nytimes.com/2017/03/14/movies/frantz-review.html",
#         "snippet": "Fran\u00e7ois Ozon\u2019s adaptation of Ernst Lubitsch\u2019s 1932 antiwar film, \u201cBroken Lullaby,\u201d is set in Germany and France in the aftermath of World War I.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Review: \u2018Frantz,\u2019 a Mysterious Frenchman and the Wounds of War",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "The Wounds of War and Love",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "creative_works",
#                 "value": "Frantz (Movie)",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Niney, Pierre",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Lubitsch, Ernst",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Ozon, Francois",
#                 "rank": 5,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2017-03-14T21:14:24+0000",
#         "byline": {
#             "original": "By Stephen Holden",
#             "person": [
#                 {
#                     "firstname": "Stephen",
#                     "middlename": null,
#                     "lastname": "Holden",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 708
#     },
#     {
#         "web_url": "https://www.nytimes.com/2017/03/09/movies/the-other-half-review-tatiana-maslany.html",
#         "snippet": "This moody romance stars Tatiana Maslany (\u201cOrphan Black\u201d) as a bipolar painter in love with a brooding cabby (Tom Cullen of \u201cDownton Abbey\u201d).",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Review: A Combustible Pair Find Love in \u2018The Other Half\u2019",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "Review: A Combustible Pair Find Love in \u2018The Other Half\u2019",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "The Other Half (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Maslany, Tatiana",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Cullen, Tom (1985- )",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Klein, Joey (Film Director)",
#                 "rank": 5,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2017-03-09T21:54:58+0000",
#         "byline": {
#             "original": "By Andy Webster",
#             "person": [
#                 {
#                     "firstname": "Andy",
#                     "middlename": null,
#                     "lastname": "Webster",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 251
#     },
#     {
#         "web_url": "https://www.nytimes.com/2017/03/09/movies/review-the-ottoman-lieutenant.html",
#         "snippet": "A nurse travels to the Ottoman Empire on the eve of World War I. Can romance blossom amid earthshaking events?",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Review: Love as the World Wars, in \u2018The Ottoman Lieutenant\u2019",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "Review: Love as the World Wars, in \u2018The Ottoman Lieutenant\u2019",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "The Ottoman Lieutenant (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Ruben, Joseph",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Hartnett, Josh",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Stockwell, Jeff (1958- )",
#                 "rank": 5,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Hilmar, Hera",
#                 "rank": 6,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Huisman, Michiel",
#                 "rank": 7,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2017-03-09T21:53:12+0000",
#         "byline": {
#             "original": "By Neil Genzlinger",
#             "person": [
#                 {
#                     "firstname": "Neil",
#                     "middlename": null,
#                     "lastname": "Genzlinger",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 267
#     },
#     {
#         "web_url": "https://www.nytimes.com/2017/03/02/movies/love-taxes-review.html",
#         "snippet": "Josh Kornbluth runs afoul of the Internal Revenue Service after failing to file tax returns for seven years.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Review: It\u2019s All Mirth and Taxes in \u2018Love & Taxes\u2019",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "It\u2019s Inevitable, Mirth and Taxes",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "creative_works",
#                 "value": "Love & Taxes (Movie)",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Kornbluth, Jacob",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Kornbluth, Josh",
#                 "rank": 4,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2017-03-02T21:44:18+0000",
#         "byline": {
#             "original": "By Ken Jaworowski",
#             "person": [
#                 {
#                     "firstname": "Ken",
#                     "middlename": null,
#                     "lastname": "Jaworowski",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 246
#     },
#     {
#         "web_url": "https://www.nytimes.com/2017/02/16/movies/everybody-loves-somebody-review.html",
#         "snippet": "A messed-up heroine is asked to choose between naughty and nice in Catalina Aguilar Mastretta\u2019s sophomore feature, which is predictable but satisfying.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Review: \u2018Everybody Loves Somebody,\u2019 a Rom-Com With Bite",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "Everybody Loves Somebody",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Everybody Loves Somebody (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Aguilar Mastretta, Catalina",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Souza, Karla (1985- )",
#                 "rank": 4,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2017-02-16T21:45:50+0000",
#         "byline": {
#             "original": "By Jeannette Catsoulis",
#             "person": [
#                 {
#                     "firstname": "Jeannette",
#                     "middlename": null,
#                     "lastname": "Catsoulis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 256
#     },
#     {
#         "web_url": "https://www.nytimes.com/2017/02/09/movies/kedi-review.html",
#         "snippet": "This documentary profiles distinctive street cats in Istanbul and the human communities that interact with them.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Review: Cute Cats of \u2018Kedi,\u2019 Rekindling a \u2018Love of Life\u2019",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "Kedi",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "creative_works",
#                 "value": "Kedi (Movie)",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Documentary Films and Programs",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Cats",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "glocations",
#                 "value": "Istanbul (Turkey)",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Torun, Ceyda",
#                 "rank": 5,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2017-02-09T16:21:39+0000",
#         "byline": {
#             "original": "By Glenn Kenny",
#             "person": [
#                 {
#                     "firstname": "Glenn",
#                     "middlename": null,
#                     "lastname": "Kenny",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 274
#     }
# ]

# %%
# Convert reviews_list to a Pandas DataFrame using json_normalize()
df = pd.json_normalize(reviews_list)
df.head()
# Out:
#                                              web_url  \
# 0  https://www.nytimes.com/2023/01/31/movies/pame...
# 1  https://www.nytimes.com/2023/01/19/movies/in-f...
# 2  https://www.nytimes.com/2023/01/19/movies/afte...
# 3  https://www.nytimes.com/2023/01/05/movies/alca...
# 4  https://www.nytimes.com/2022/12/15/movies/nell...
#
#                                              snippet              source  \
# 0  This documentary from Ryan White rewinds, to p...  The New York Times
# 1  In Matt Carter’s gay rugby film, sports and ro...  The New York Times
# 2  In this intelligent melodrama by the director ...  The New York Times
# 3  In this naturalistic drama from Spain, a famil...  The New York Times
# 4  A family archive provides intimate records of ...  The New York Times
#
#                                             keywords  \
# 0  [{'name': 'subject', 'value': 'Documentary Fil...
# 1  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 2  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 3  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 4  [{'name': 'subject', 'value': 'Documentary Fil...
#
#                    pub_date  word_count  \
# 0  2023-01-31T12:00:05+0000         295
# 1  2023-01-19T17:50:16+0000         281
# 2  2023-01-19T12:00:06+0000         359
# 3  2023-01-05T12:00:03+0000         306
# 4  2022-12-15T12:00:04+0000         308
#
#                                        headline.main headline.kicker  \
# 0   ‘Pamela, a Love Story’ Review: A Frank Look Back            None
# 1  ‘In From the Side’ Review: Love and Rugby Play...            None
# 2               ‘After Love’ Review: The Other Woman   Critic’s Pick
# 3                   ‘Alcarràs’ Review: Labor of Love            None
# 4  ‘Nelly & Nadine’ Review: An Unlikely Love, an ...            None
#
#   headline.content_kicker headline.print_headline headline.name headline.seo  \
# 0                    None    Pamela, a Love Story          None         None
# 1                    None        In From the Side          None         None
# 2                    None              After Love          None         None
# 3                    None                Alcarràs          None         None
# 4                    None      Nelly &amp; Nadine          None         None
#
#   headline.sub     byline.original  \
# 0         None      By Glenn Kenny
# 1         None      By Kyle Turner
# 2         None  By Beatrice Loayza
# 3         None    By Devika Girish
# 4         None       By Teo Bugbee
#
#                                        byline.person byline.organization
# 0  [{'firstname': 'Glenn', 'middlename': None, 'l...                None
# 1  [{'firstname': 'Kyle', 'middlename': None, 'la...                None
# 2  [{'firstname': 'Beatrice', 'middlename': None,...                None
# 3  [{'firstname': 'Devika', 'middlename': None, '...                None
# 4  [{'firstname': 'Teo', 'middlename': None, 'las...                None

# %%
def extract_title(x):
    try:
        # find start and end index
        start_idx = x.index('‘')+1
        end_idx = x.index('’')

        # After getting blank titles and doing research
        # I found that some strings had multiple of the closing comma
        # this while loop handles finding the correct closing character if there are multiple
        while end_idx < start_idx:
            end_idx = x[end_idx+1 : len(x)].index('’') + end_idx + 1

        # build string with the title
        s = x[int(start_idx): int(end_idx)]

        # check if title is blank and set as NaN or return the title
        return s if s != '' else np.nan
    except:
        return np.nan

# Extract the title from the "headline.main" column and
# save it to a new column "title"
# Title is between unicode characters \u2018 and \u2019. 
# End string should include " Review" to avoid cutting title early

df['Title'] = df['headline.main'].apply(extract_title)

# clear rows that have a blank Title
#df.dropna(subset=['Title'], inplace=True, how='any', axis = 'rows')

# print 5 rows to see the new Title column
df.head()

# check there are no blank rows
#df['Title'].loc[df['Title'] == '']
# Out:
#                                              web_url  \
# 0  https://www.nytimes.com/2023/01/31/movies/pame...
# 1  https://www.nytimes.com/2023/01/19/movies/in-f...
# 2  https://www.nytimes.com/2023/01/19/movies/afte...
# 3  https://www.nytimes.com/2023/01/05/movies/alca...
# 4  https://www.nytimes.com/2022/12/15/movies/nell...
#
#                                              snippet              source  \
# 0  This documentary from Ryan White rewinds, to p...  The New York Times
# 1  In Matt Carter’s gay rugby film, sports and ro...  The New York Times
# 2  In this intelligent melodrama by the director ...  The New York Times
# 3  In this naturalistic drama from Spain, a famil...  The New York Times
# 4  A family archive provides intimate records of ...  The New York Times
#
#                                             keywords  \
# 0  [{'name': 'subject', 'value': 'Documentary Fil...
# 1  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 2  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 3  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 4  [{'name': 'subject', 'value': 'Documentary Fil...
#
#                    pub_date  word_count  \
# 0  2023-01-31T12:00:05+0000         295
# 1  2023-01-19T17:50:16+0000         281
# 2  2023-01-19T12:00:06+0000         359
# 3  2023-01-05T12:00:03+0000         306
# 4  2022-12-15T12:00:04+0000         308
#
#                                        headline.main headline.kicker  \
# 0   ‘Pamela, a Love Story’ Review: A Frank Look Back            None
# 1  ‘In From the Side’ Review: Love and Rugby Play...            None
# 2               ‘After Love’ Review: The Other Woman   Critic’s Pick
# 3                   ‘Alcarràs’ Review: Labor of Love            None
# 4  ‘Nelly & Nadine’ Review: An Unlikely Love, an ...            None
#
#   headline.content_kicker headline.print_headline headline.name headline.seo  \
# 0                    None    Pamela, a Love Story          None         None
# 1                    None        In From the Side          None         None
# 2                    None              After Love          None         None
# 3                    None                Alcarràs          None         None
# 4                    None      Nelly &amp; Nadine          None         None
#
#   headline.sub     byline.original  \
# 0         None      By Glenn Kenny
# 1         None      By Kyle Turner
# 2         None  By Beatrice Loayza
# 3         None    By Devika Girish
# 4         None       By Teo Bugbee
#
#                                        byline.person byline.organization  \
# 0  [{'firstname': 'Glenn', 'middlename': None, 'l...                None
# 1  [{'firstname': 'Kyle', 'middlename': None, 'la...                None
# 2  [{'firstname': 'Beatrice', 'middlename': None,...                None
# 3  [{'firstname': 'Devika', 'middlename': None, '...                None
# 4  [{'firstname': 'Teo', 'middlename': None, 'las...                None
#
#                   Title
# 0  Pamela, a Love Story
# 1      In From the Side
# 2            After Love
# 3              Alcarràs
# 4        Nelly & Nadine

# %%
# Extract 'name' and 'value' from items in "keywords" column
def extract_keywords(keyword_list):
    extracted_keywords = ""
    for item in keyword_list:
        # Extract 'name' and 'value'
        keyword = f"{item['name']}: {item['value']};" 
        # Append the keyword item to the extracted_keywords list
        extracted_keywords += keyword
    return extracted_keywords

# Fix the "keywords" column by converting cells from a list to a string
df['keywords'] = df['keywords'].apply(extract_keywords)
df['keywords'].head()
# Out:
# 0    subject: Documentary Films and Programs;person...
# 1    subject: Movies;creative_works: In From the Si...
# 2    subject: Movies;creative_works: After Love (20...
# 3    subject: Movies;persons: Simon, Carla;creative...
# 4    subject: Documentary Films and Programs;person...
# Name: keywords, dtype: object

# %%
# Create a list from the "title" column using to_list()
# These titles will be used in the query for The Movie Database
title_list = df['Title'].to_list()
title_list
# Out:
# ['Pamela, a Love Story',
#  'In From the Side',
#  'After Love',
#  'Alcarràs',
#  'Nelly & Nadine',
#  'Lady Chatterley',
#  'The Sound of Christmas',
#  'The Inspection',
#  'Bones and All',
#  'My Policeman',
#  'About Fate',
#  'Waiting for Bojangles',
#  'I Love My Dad',
#  'A Love Song',
#  'Alone Together',
#  'Art of Love',
#  'The Wheel',
#  'Thor: Love and Thunder',
#  'Both Sides of the Blade',
#  'Fire of Love',
#  'Love & Gelato',
#  'Stay Prayed Up',
#  'Benediction',
#  'Dinner in America',
#  'In a New York Minute',
#  'Anaïs in Love',
#  'I Love America',
#  'See You Then',
#  'La Mami',
#  'Love After Love',
#  'Deep Water',
#  'Lucy and Desi',
#  'Cyrano',
#  'The In Between',
#  'Book of Love',
#  'Lingui, the Sacred Bonds',
#  'The Pink Cloud',
#  'A Journal for Jordan',
#  'West Side Story',
#  'Aulcie',
#  'Love Is Love Is Love',
#  'Love Hard',
#  'Bergman Island',
#  'Hard Luck Love Song',
#  'South of Heaven',
#  'Wife of a Spy',
#  'Happier Than Ever',
#  'Together',
#  'Annette',
#  'Resort to Love',
#  'Woodstock 99: Peace, Love and Rage',
#  'Casanova, Last Love',
#  'Running Against the Wind',
#  'Asia',
#  'Undine',
#  'This Town',
#  'Tu Me Manques',
#  'Monday',
#  'Ride or Die',
#  'Future People',
#  'Luz',
#  'Happily',
#  'This Is the Life',
#  'To All the Boys: Always and Forever',
#  'Young Hearts',
#  'Little Fish',
#  'Two of Us',
#  'Atlantis',
#  'Preparations to Be Together',
#  'Your Name Engraved Herein',
#  'Sylvie',
#  'Ariana Grande: Excuse Me, I Love You',
#  'Museum Town',
#  'Wild Mountain Thyme',
#  'My Psychedelic Love Story',
#  '69: The Saga of Danny Hernandez',
#  'Ammonite',
#  'Love and Monsters',
#  'Dick Johnson Is Dead',
#  'Love, Guaranteed',
#  'Feel the Beat',
#  'Babyteeth',
#  'Spelling the Dream',
#  'A Secret Love',
#  'Love Wedding Repeat',
#  'Almost Love',
#  'Hope Gap',
#  'All the Bright Places',
#  'The Photograph',
#  'You Go to My Head',
#  'Ordinary Love',
#  'To All the Boys: P.S. I Still Love You',
#  'The Woman Who Loves Giraffes',
#  'Queen & Slim',
#  'Marriage Story',
#  'Cyrano, My Love',
#  'Pretenders',
#  'First Love',
#  'Loro',
#  'Falling Inn Love',
#  'Hot Air',
#  'Love, Antosha',
#  'Leto',
#  'The Tomorrow Man',
#  'Asako I & II',
#  'The Sun Is Also a Star',
#  'Shéhérazade',
#  'Long Shot',
#  'Clara',
#  'Kalank',
#  'Rafiki',
#  'Diane',
#  'Five Feet Apart',
#  'Ash Is Purest White',
#  'Gloria Bell',
#  'Black Mother',
#  'The Hole in the Ground',
#  'How to Train Your Dragon: The Hidden World',
#  'A Tuba to Cuba',
#  'Fighting With My Family',
#  'Sorry Angel',
#  'Berlin, I Love You',
#  'Untogether',
#  'Cold War',
#  'If Beale Street Could Talk',
#  'Asher',
#  'The Party',
#  'The Great Pretender',
#  'Sicilian Ghost Story',
#  'The New Romantic',
#  'Pimp',
#  'In a Relationship',
#  'They',
#  'Burning,',
#  'After Everything,',
#  'Quincy',
#  'Love, Gilda,',
#  'Tea With the Dames,',
#  'Bel Canto,',
#  'The Citizen,',
#  'Love, Cecil,',
#  'How to Talk to Girls at Parties',
#  'Rogers Park,',
#  'Love & Bananas,',
#  'Godard Mon Amour',
#  'Submergence,',
#  'Love After Love,',
#  'Outside In',
#  'Love, Simon,',
#  'Keep the Change,',
#  'The Party',
#  'The Housemaid,',
#  'Forever My Girl,',
#  'Kangaroo: A Love-Hate Story',
#  'Lover for a Day',
#  'Youth,',
#  'Killing for Love',
#  'The Shape of Water',
#  'Love Beats Rhymes,',
#  'Cuba and the Cameraman',
#  'On the Beach at Night Alone',
#  'Thelma,',
#  'Hello Again,',
#  'It Happened in L.A.,',
#  'God',
#  'The Mountain Between Us',
#  'Dina,',
#  'In Search of Fellini',
#  'Woodpeckers,',
#  'I Do ... Until I Don',
#  'Tales of an Immoral Couple',
#  'After Love',
#  'The Last Face',
#  'Women Who Kill,',
#  'False Confessions,',
#  nan,
#  'The Big Sick,',
#  'Lost in Paris',
#  'Vincent N Roxxy,',
#  'Everything, Everything',
#  'Hounds of Love',
#  'Harold and Lillian',
#  'The Happiest Day in the Life of Olli Maki,',
#  'The Promise',
#  'Frantz,',
#  'The Other Half',
#  'The Ottoman Lieutenant',
#  'Love & Taxes',
#  'Everybody Loves Somebody,',
#  'Kedi,']

# %% [markdown]
# ### Access The Movie Database API

# %%
# Prepare The Movie Database query

tmdb_key_string = f"?api_key={tmdb_api_key}"
url_search = f"https://api.themoviedb.org/3/search/movie{tmdb_key_string}&query="
url_detail = f"https://api.themoviedb.org/3/movie/"

# %%
# Test out API calls

test_resp = requests.get(url_search + title_list[0].replace(' ', '+')).json()['results'][0]

test_resp2 = requests.get(url_detail + str(test_resp['id']) + tmdb_key_string).json()

#resp2['genres'] = [{'id': 99, 'name': 'Documentary'}]
#resp2['production_countries'] = [{'iso_3166_1': 'US','name': 'United States of America'}]
#resp2['spoken_languages'] = [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}]

test_resp2
# Out:
# {'adult': False,
#  'backdrop_path': '/aJvgoRMrYFTMu7MrcfxYVPMRuU5.jpg',
#  'belongs_to_collection': None,
#  'budget': 0,
#  'genres': [{'id': 99, 'name': 'Documentary'}],
#  'homepage': 'https://www.netflix.com/title/81590934',
#  'id': 1061671,
#  'imdb_id': 'tt18376122',
#  'origin_country': ['US'],
#  'original_language': 'en',
#  'original_title': 'Pamela, A Love Story',
#  'overview': 'In her own words, through personal video and diaries, Pamela Anderson shares the story of her rise to fame, rocky romances and infamous sex tape scandal.',
#  'popularity': 17.091,
#  'poster_path': '/zkVnRwZWbrd55P3Tx7BZZQ1gU89.jpg',
#  'production_companies': [{'id': 90561,
#    'logo_path': None,
#    'name': 'Tripod Media',
#    'origin_country': 'US'},
#   {'id': 135005,
#    'logo_path': '/yHs7fh3S2JEDdYX5B0UrA5lSTjN.png',
#    'name': 'Dorothy St Pictures',
#    'origin_country': 'GB'}],
#  'production_countries': [{'iso_3166_1': 'US',
#    'name': 'United States of America'}],
#  'release_date': '2023-01-30',
#  'revenue': 0,
#  'runtime': 113,
#  'spoken_languages': [{'english_name': 'English',
#    'iso_639_1': 'en',
#    'name': 'English'}],
#  'status': 'Released',
#  'tagline': 'She defined a decade. Now she will define herself.',
#  'title': 'Pamela, A Love Story',
#  'video': False,
#  'vote_average': 7.0,
#  'vote_count': 202}

# %%
# static map to prevent making more callouts if I have the title stored
tmdb_movies_map = {}

# %%
# Create an empty list to store the results
tmdb_movies_list = []

# Create a request counter to sleep the requests after a multiple
# of 50 requests
request_counter = 1

# Loop through the titles
for title in title_list:

    if title in tmdb_movies_map:
        print('title already found.')
        continue

    # Check if we need to sleep before making a request
    if request_counter % 50 == 0:
        print('Sleeping for 1 second.')
        time.sleep(1)

    # Add 1 to the request counter
    request_counter += 1

    
    # Perform a "GET" request for The Movie Database
    resp1

    try:
        resp1 = requests.get(url_search + title.replace(' ', '+')).json()['results']
    except:
        print('Failed on search', title)
        continue

    # Include a try clause to search for the full movie details.
    # Use the except clause to print out a statement if a movie
    # is not found.
    try:
        resp1 = resp1[0]
        # Get movie id
        # Make a request for a the full movie details
        # Execute "GET" request with url
        resp2 = requests.get(url_detail + str(resp1['id']) + tmdb_key_string).json()
        
        # Extract the genre names into a list
        # Extract the spoken_languages' English name into a list
        # Extract the production_countries' name into a list
        # Add the relevant data to a dictionary and
        # append it to the tmdb_movies_list list
        data = {
            'title': title,
            'original_title': resp2['original_title'],
            'budget': resp2['budget'],
            'original_language': resp2['original_language'],
            'homepage': resp2['homepage'],
            'overview': resp2['overview'],
            'popularity': resp2['popularity'],
            'runtime': resp2['runtime'],
            'revenue': resp2['revenue'],
            'release_date': resp2['release_date'],
            'vote_average': resp2['vote_average'],
            'vote_count': resp2['vote_count'],
            'genres': resp2['genres'],
            'spoken_languages': resp2['spoken_languages'],
            'production_countries': resp2['production_countries']
        }
        
        tmdb_movies_list.append(data)
        tmdb_movies_map[title] = data
        
        # Print out the title that was found
        print(f'Found Title: "{title}"')
    except Exception as error:
        print(error, f'Title "{title}" not found.')
# Out:
# Found Title: "Pamela, a Love Story"
# Found Title: "In From the Side"
# Found Title: "After Love"
# Found Title: "Alcarràs"
# Found Title: "Nelly & Nadine"
# Found Title: "Lady Chatterley"
# Found Title: "The Sound of Christmas"
# Found Title: "The Inspection"
# Found Title: "Bones and All"
# Found Title: "My Policeman"
# Found Title: "About Fate"
# Found Title: "Waiting for Bojangles"
# Found Title: "I Love My Dad"
# Found Title: "A Love Song"
# Found Title: "Alone Together"
# Found Title: "Art of Love"
# Found Title: "The Wheel"
# Found Title: "Thor: Love and Thunder"
# Found Title: "Both Sides of the Blade"
# Found Title: "Fire of Love"
# Found Title: "Love & Gelato"
# Found Title: "Stay Prayed Up"
# Found Title: "Benediction"
# Found Title: "Dinner in America"
# Found Title: "In a New York Minute"
# Found Title: "Anaïs in Love"
# Found Title: "I Love America"
# Found Title: "See You Then"
# Found Title: "La Mami"
# Found Title: "Love After Love"
# Found Title: "Deep Water"
# Found Title: "Lucy and Desi"
# Found Title: "Cyrano"
# Found Title: "The In Between"
# Found Title: "Book of Love"
# Found Title: "Lingui, the Sacred Bonds"
# Found Title: "The Pink Cloud"
# Found Title: "A Journal for Jordan"
# Found Title: "West Side Story"
# list index out of range Title "Aulcie" not found.
# Found Title: "Love Is Love Is Love"
# Found Title: "Love Hard"
# Found Title: "Bergman Island"
# Found Title: "Hard Luck Love Song"
# Found Title: "South of Heaven"
# Found Title: "Wife of a Spy"
# Found Title: "Happier Than Ever"
# Found Title: "Together"
# Found Title: "Annette"
# Sleeping for 1 second.
# Found Title: "Resort to Love"
# Found Title: "Woodstock 99: Peace, Love and Rage"
# Found Title: "Casanova, Last Love"
# Found Title: "Running Against the Wind"
# Found Title: "Asia"
# Found Title: "Undine"
# Found Title: "This Town"
# Found Title: "Tu Me Manques"
# Found Title: "Monday"
# Found Title: "Ride or Die"
# Found Title: "Future People"
# Found Title: "Luz"
# Found Title: "Happily"
# Found Title: "This Is the Life"
# Found Title: "To All the Boys: Always and Forever"
# Found Title: "Young Hearts"
# Found Title: "Little Fish"
# Found Title: "Two of Us"
# Found Title: "Atlantis"
# Found Title: "Preparations to Be Together"
# Found Title: "Your Name Engraved Herein"
# Found Title: "Sylvie"
# Found Title: "Ariana Grande: Excuse Me, I Love You"
# Found Title: "Museum Town"
# Found Title: "Wild Mountain Thyme"
# Found Title: "My Psychedelic Love Story"
# Found Title: "69: The Saga of Danny Hernandez"
# Found Title: "Ammonite"
# Found Title: "Love and Monsters"
# Found Title: "Dick Johnson Is Dead"
# Found Title: "Love, Guaranteed"
# Found Title: "Feel the Beat"
# Found Title: "Babyteeth"
# Found Title: "Spelling the Dream"
# Found Title: "A Secret Love"
# Found Title: "Love Wedding Repeat"
# Found Title: "Almost Love"
# Found Title: "Hope Gap"
# Found Title: "All the Bright Places"
# Found Title: "The Photograph"
# Found Title: "You Go to My Head"
# Found Title: "Ordinary Love"
# Found Title: "To All the Boys: P.S. I Still Love You"
# Found Title: "The Woman Who Loves Giraffes"
# Found Title: "Queen & Slim"
# Found Title: "Marriage Story"
# Found Title: "Cyrano, My Love"
# Found Title: "Pretenders"
# Found Title: "First Love"
# Found Title: "Loro"
# Sleeping for 1 second.
# Found Title: "Falling Inn Love"
# Found Title: "Hot Air"
# Found Title: "Love, Antosha"
# Found Title: "Leto"
# Found Title: "The Tomorrow Man"
# Found Title: "Asako I & II"
# Found Title: "The Sun Is Also a Star"
# Found Title: "Shéhérazade"
# Found Title: "Long Shot"
# Found Title: "Clara"
# Found Title: "Kalank"
# Found Title: "Rafiki"
# Found Title: "Diane"
# Found Title: "Five Feet Apart"
# Found Title: "Ash Is Purest White"
# Found Title: "Gloria Bell"
# Found Title: "Black Mother"
# Found Title: "The Hole in the Ground"
# Found Title: "How to Train Your Dragon: The Hidden World"
# Found Title: "A Tuba to Cuba"
# Found Title: "Fighting With My Family"
# Found Title: "Sorry Angel"
# Found Title: "Berlin, I Love You"
# Found Title: "Untogether"
# Found Title: "Cold War"
# Found Title: "If Beale Street Could Talk"
# Found Title: "Asher"
# Found Title: "The Party"
# Found Title: "The Great Pretender"
# Found Title: "Sicilian Ghost Story"
# Found Title: "The New Romantic"
# Found Title: "Pimp"
# Found Title: "In a Relationship"
# Found Title: "They"
# Found Title: "Burning,"
# Found Title: "After Everything,"
# Found Title: "Quincy"
# Found Title: "Love, Gilda,"
# Found Title: "Tea With the Dames,"
# Found Title: "Bel Canto,"
# Found Title: "The Citizen,"
# Found Title: "Love, Cecil,"
# Found Title: "How to Talk to Girls at Parties"
# Found Title: "Rogers Park,"
# Found Title: "Love & Bananas,"
# Found Title: "Godard Mon Amour"
# Found Title: "Submergence,"
# Found Title: "Love After Love,"
# Found Title: "Outside In"
# Found Title: "Love, Simon,"
# Sleeping for 1 second.
# Found Title: "Keep the Change,"
# title already found.
# Found Title: "The Housemaid,"
# Found Title: "Forever My Girl,"
# Found Title: "Kangaroo: A Love-Hate Story"
# Found Title: "Lover for a Day"
# Found Title: "Youth,"
# Found Title: "Killing for Love"
# Found Title: "The Shape of Water"
# Found Title: "Love Beats Rhymes,"
# Found Title: "Cuba and the Cameraman"
# Found Title: "On the Beach at Night Alone"
# Found Title: "Thelma,"
# Found Title: "Hello Again,"
# Found Title: "It Happened in L.A.,"
# Found Title: "God"
# Found Title: "The Mountain Between Us"
# Found Title: "Dina,"
# Found Title: "In Search of Fellini"
# Found Title: "Woodpeckers,"
# Found Title: "I Do ... Until I Don"
# Found Title: "Tales of an Immoral Couple"
# title already found.
# Found Title: "The Last Face"
# Found Title: "Women Who Kill,"
# Found Title: "False Confessions,"
# Failed on search nan
# Found Title: "The Big Sick,"
# Found Title: "Lost in Paris"
# Found Title: "Vincent N Roxxy,"
# Found Title: "Everything, Everything"
# Found Title: "Hounds of Love"
# Found Title: "Harold and Lillian"
# Found Title: "The Happiest Day in the Life of Olli Maki,"
# Found Title: "The Promise"
# Found Title: "Frantz,"
# Found Title: "The Other Half"
# Found Title: "The Ottoman Lieutenant"
# Found Title: "Love & Taxes"
# Found Title: "Everybody Loves Somebody,"
# Found Title: "Kedi,"

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data
print(json.dumps(tmdb_movies_list, sort_keys=True, indent=4))
# Out:
# [
#     {
#         "budget": 0,
#         "genres": [
#             {
#                 "id": 99,
#                 "name": "Documentary"
#             }
#         ],
#         "homepage": "https://www.netflix.com/title/81590934",
#         "original_language": "en",
#         "original_title": "Pamela, A Love Story",
#         "overview": "In her own words, through personal video and diaries, Pamela Anderson shares the story of her rise to fame, rocky romances and infamous sex tape scandal.",
#         "popularity": 17.091,
#         "production_countries": [
#             {
#                 "iso_3166_1": "US",
#                 "name": "United States of America"
#             }
#         ],
#         "release_date": "2023-01-30",
#         "revenue": 0,
#         "runtime": 113,
#         "spoken_languages": [
#             {
#                 "english_name": "English",
#                 "iso_639_1": "en",
#                 "name": "English"
#             }
#         ],
#         "title": "Pamela, a Love Story",
#         "vote_average": 7.0,
#         "vote_count": 202
#     },
#     {
#         "budget": 0,
#         "genres": [
#             {
#                 "id": 18,
#                 "name": "Drama"
#             },
#             {
#                 "id": 10749,
#                 "name": "Romance"
#             }
#         ],
#         "homepage": "http://www.infromthesidemovie.com",
#         "original_language": "en",
#         "original_title": "In from the Side",
#         "overview": "Mark, a new and inexperienced rugby club member, finds himself drawn to Warren, a seasoned first team player. When a series of happenstances at an away fixture lead to a drunken encounter, Mark and Warren unwittingly embark on a romantic affair they struggle to hide from their partners and teammates.",
#         "popularity": 14.059,
#         "production_countries": [
#             {
#                 "iso_3166_1": "GB",
#                 "name": "United Kingdom"
#             }
#         ],
#         "release_date": "2022-09-16",
#         "revenue": 0,
#         "runtime": 134,
#         "spoken_languages": [
#             {
#                 "english_name": "English",
#                 "iso_639_1": "en",
#                 "name": "English"
#             }
#         ],
#         "title": "In From the Side",
#         "vote_average": 6.78,
#         "vote_count": 59
#     },
#     {
#         "budget": 0,
#         "genres": [
#             {
#                 "id": 18,
#                 "name": "Drama"
#             }
#         ],
#         "homepage": "",
#         "original_language": "en",
#         "original_title": "After Love",
#         "overview": "Set in the port town of Dover in the South-East of England, Mary Hussain suddenly finds herself a widow following the unexpected death of her husband. A day after the burial, she discovers he has a secret just twenty-one miles across the English Channel in Calais.",
#         "popularity": 15.106,
#         "production_countries": [
#             {
#                 "iso_3166_1": "GB",
#                 "name": "United Kingdom"
#             }
#         ],
#         "release_date": "2021-06-04",
#         "revenue": 0,
#         "runtime": 89,
#         "spoken_languages": [
#             {
#                 "english_name": "English",
#                 "iso_639_1": "en",
#                 "name": "English"
#             },
#             {
#                 "english_name": "Arabic",
#                 "iso_639_1": "ar",
#                 "name": "\u0627\u0644\u0639\u0631\u0628\u064a\u0629"
#             },
#             {
#                 "english_name": "French",
#                 "iso_639_1": "fr",
#                 "name": "Fran\u00e7ais"
#             },
#             {
#                 "english_name": "Urdu",
#                 "iso_639_1": "ur",
#                 "name": "\u0627\u0631\u062f\u0648"
#             }
#         ],
#         "title": "After Love",
#         "vote_average": 7.155,
#         "vote_count": 116
#     },
#     {
#         "budget": 0,
#         "genres": [
#             {
#                 "id": 18,
#                 "name": "Drama"
#             }
#         ],
#         "homepage": "https://www.alcarras-film.com/",
#         "original_language": "ca",
#         "original_title": "Alcarr\u00e0s",
#         "overview": "In a small village in Catalonia, the peach farmers of the Sol\u00e9 family spend every summer together picking fruit from their orchard. But when plans arise to install solar panels and cut down trees, the members of this tight-knit group suddenly face eviction \u2013 and the loss of far more than their home.",
#         "popularity": 11.358,
#         "production_countries": [
#             {
#                 "iso_3166_1": "ES",
#                 "name": "Spain"
#             }
#         ],
#         "release_date": "2022-04-29",
#         "revenue": 0,
#         "runtime": 120,
#         "spoken_languages": [
#             {
#                 "english_name": "Catalan",
#                 "iso_639_1": "ca",
#                 "name": "Catal\u00e0"
#             }
#         ],
#         "title": "Alcarr\u00e0s",
#         "vote_average": 6.867,
#         "vote_count": 173
#     },
#     {
#         "budget": 0,
#         "genres": [
#             {
#                 "id": 18,
#                 "name": "Drama"
#             },
#             {
#                 "id": 10749,
#                 "name": "Romance"
#             }
#         ],
#         "homepage": "",
#         "original_language": "fr",
#         "original_title": "Nelly et Mr. Arnaud",
#         "overview": "Nelly leaves her lazy, unemployed husband to work for retired judge Mr Arnaud, forty years her senior, after he offers to clear her bills for her. While she types his memoirs the two develop a close friendship, but Arnaud becomes jealous when Nelly begins dating his good-looking young publisher.",
#         "popularity": 15.88,
#         "production_countries": [
#             {
#                 "iso_3166_1": "DE",
#                 "name": "Germany"
#             },
#             {
#                 "iso_3166_1": "FR",
#                 "name": "France"
#             },
#             {
#                 "iso_3166_1": "IT",
#                 "name": "Italy"
#             }
#         ],
#         "release_date": "1995-08-23",
#         "revenue": 0,
#         "runtime": 106,
#         "spoken_languages": [
#             {
#                 "english_name": "French",
#                 "iso_639_1": "fr",
#                 "name": "Fran\u00e7ais"
#             }
#         ],
#         "title": "Nelly & Nadine",
#         "vote_average": 6.9,
#         "vote_count": 116
#     },
#     {
#         "budget": 0,
#         "genres": [
#             {
#                 "id": 18,
#                 "name": "Drama"
#             },
#             {
#                 "id": 10749,
#                 "name": "Romance"
#             }
#         ],
#         "homepage": "http://www.kino.com/ladychatterley/#Scene_1",
#         "original_language": "fr",
#         "original_title": "Lady Chatterley",
#         "overview": "In the Chatterley country estate, monotonous days follow one after the other for Constance, trapped by her marriage and her sense of duty. During spring, deep in the heart of Wragby forest, she encounters Parkin, the estate\u2019s gamekeeper. A tale of an encounter, a difficult apprenticeship, a slow awakening to sensuality for her, a long return to life for him. Or how love is but one with experience and transformation.",
#         "popularity": 19.697,
#         "production_countries": [
#             {
#                 "iso_3166_1": "BE",
#                 "name": "Belgium"
#             },
#             {
#                 "iso_3166_1": "FR",
#                 "name": "France"
#             },
#             {
#                 "iso_3166_1": "GB",
#                 "name": "United Kingdom"
#             }
#         ],
#         "release_date": "2006-11-01",
#         "revenue": 0,
#         "runtime": 167,
#         "spoken_languages": [
#             {
#                 "english_name": "French",
#                 "iso_639_1": "fr",
#                 "name": "Fran\u00e7ais"
#             }
#         ],
#         "title": "Lady Chatterley",
#         "vote_average": 6.2,
#         "vote_count": 99
#     },
#     {
#         "budget": 0,
#         "genres": [
#             {
#                 "id": 10770,
#                 "name": "TV Movie"
#             },
#             {
#                 "id": 18,
#                 "name": "Drama"
#             }
#         ],
#         "homepage": "",
#         "original_language": "en",
#         "original_title": "The Sound of Christmas",
#         "overview": "A woman facing eviction just before Christmas who must navigate budding romantic feelings for a handsome billionaire when she takes a job nannying for his two children right before Christmas.",
#         "popularity": 2.621,
#         "production_countries": [
#             {
#                 "iso_3166_1": "US",
#                 "name": "United States of America"
#             }
#         ],
#         "release_date": "2022-11-24",
#         "revenue": 0,
#         "runtime": 0,
#         "spoken_languages": [
#             {
#                 "english_name": "English",
#                 "iso_639_1": "en",
#                 "name": "English"
#             }
#         ],
#         "title": "The Sound of Christmas",
#         "vote_average": 8.0,
#         "vote_count": 4
#     },
#     {
#         "budget": 0,
#         "genres": [
#             {
#                 "id": 18,
#                 "name": "Drama"
#             }
#         ],
#         "homepage": "https://a24films.com/films/inspection",
#         "original_language": "en",
#         "original_title": "The Inspection",
#         "overview": "Ellis French is a young, gay Black man, rejected by his mother and with few options for his future, decides to join the Marines, doing whatever it takes to succeed in a system that would cast him aside. But even as he battles deep-seated prejudice and the grueling routines of basic training, he finds unexpected camaraderie, strength, and support in this new community, giving him a hard-earned sense of belonging that will shape his identity and forever change his life.",
#         "popularity": 21.002,
#         "production_countries": [
#             {
#                 "iso_3166_1": "US",
#                 "name": "United States of America"
#             }
#         ],
#         "release_date": "2022-11-18",
#         "revenue": 270613,
#         "runtime": 95,
#         "spoken_languages": [
#             {
#                 "english_name": "Arabic",
#                 "iso_639_1": "ar",
#                 "name": "\u0627\u0644\u0639\u0631\u0628\u064a\u0629"
#             },
#             {
#                 "english_name": "Spanish",
#                 "iso_639_1": "es",
#                 "name": "Espa\u00f1ol"
#             },
#             {
#                 "english_name": "English",
#                 "iso_639_1": "en",
#                 "name": "English"
#             }
#         ],
#         "title": "The Inspection",
#         "vote_average": 6.1,
#         "vote_count": 53
#     },
#     {
#         "budget": 18000000,
#         "genres": [
#             {
#                 "id": 18,
#                 "name": "Drama"
#             },
#             {
#                 "id": 27,
#                 "name": "Horror"
#             },
#             {
#                 "id": 10749,
#                 "name": "Romance"
#             }
#         ],
#         "homepage": "https://www.bonesandallfilm.net/",
#         "original_language": "it",
#         "original_title": "Bones and All",
#         "overview": "Abandoned by her father, a young woman embarks on a thousand-mile odyssey through the backroads of America where she meets a disenfranchised drifter. But despite their best efforts, all roads lead back to their terrifying pasts and to a final stand that will determine whether their love can survive their otherness.",
#         "popularity": 38.023,
#         "production_countries": [
#             {
#                 "iso_3166_1": "IT",
#                 "name": "Italy"
#             },
#             {
#                 "iso_3166_1": "US",
#                 "name": "United States of America"
#             }
#         ],
#         "release_date": "2022-11-18",
#         "revenue": 15100000,
#         "runtime": 131,
#         "spoken_languages": [
#             {
#                 "english_name": "English",
#                 "iso_639_1": "en",
#                 "name": "English"
#             }
#         ],
#         "title": "Bones and All",
#         "vote_average": 7.076,
#         "vote_count": 1212
#     },
#     {
#         "budget": 0,
#         "genres": [
#             {
#                 "id": 18,
#                 "name": "Drama"
#             },
#             {
#                 "id": 10749,
#                 "name": "Romance"
#             }
#         ],
#         "homepage": "https://www.amazon.com/dp/B09Y8SHDPD",
#         "original_language": "en",
#         "original_title": "My Policeman",
#         "overview": "In the late 1990s, the arrival of elderly invalid Patrick into Marion and Tom\u2019s home triggers the exploration of seismic events from 40 years previous: the passionate relationship between Tom and Patrick at a time when homosexuality was illegal.",
#         "popularity": 27.091,
#         "production_countries": [
#             {
#                 "iso_3166_1": "GB",
#                 "name": "United Kingdom"
#             },
#             {
#                 "iso_3166_1": "US",
#                 "name": "United States of America"
#             }
#         ],
#         "release_date": "2022-10-20",
#         "revenue": 0,
#         "runtime": 113,
#         "spoken_languages": [
#             {
#                 "english_name": "English",
#                 "iso_639_1": "en",
#                 "name": "English"
#             }
#         ],
#         "title": "My Policeman",
#         "vote_average": 7.731,
#         "vote_count": 635
#     },
#     {
#         "budget": 0,
#         "genres": [
#             {
#                 "id": 10749,
#                 "name": "Romance"
#             },
#             {
#                 "id": 35,
#                 "name": "Comedy"
#             }
#         ],
#         "homepage": "",
#         "original_language": "en",
#         "original_title": "About Fate",
#         "overview": "Two strangers believe in love but never seem to be able to find its true meaning. In a wild twist of events, fate puts each in the other's path on one stormy New Year's Eve.",
#         "popularity": 35.007,
#         "production_countries": [
#             {
#                 "iso_3166_1": "US",
#                 "name": "United States of America"
#             }
#         ],
#         "release_date": "2022-09-08",
#         "revenue": 0,
#         "runtime": 100,
#         "spoken_languages": [
#             {
#                 "english_name": "English",
#                 "iso_639_1": "en",
#                 "name": "English"
#             }
#         ],
#         "title": "About Fate",
#         "vote_average": 7.48,
#         "vote_count": 357
#     },
#     {
#         "budget": 0,
#         "genres": [
#             {
#                 "id": 18,
#                 "name": "Drama"
#             },
#             {
#                 "id": 35,
#                 "name": "Comedy"
#             },
#             {
#                 "id": 10749,
#                 "name": "Romance"
#             }
#         ],
#         "homepage": "",
#         "original_language": "fr",
#         "original_title": "En attendant Bojangles",
#         "overview": "A boy and his eccentric parents leave their home in Paris for a country house in Spain. As the mother descends deeper into her own mind, it's up to the boy and his father to keep her safe and happy.",
#         "popularity": 9.868,
#         "production_countries": [
#             {
#                 "iso_3166_1": "FR",
#                 "name": "France"
#             },
#             {
#                 "iso_3166_1": "US",
#                 "name": "United States of America"
#             }
#         ],
#         "release_date": "2021-10-13",
#         "revenue": 0,
#         "runtime": 124,
#         "spoken_languages": [
#             {
#                 "english_name": "English",
#                 "iso_639_1": "en",
#                 "name": "English"
#             },
#             {
#                 "english_name": "French",
#                 "iso_639_1": "fr",
#                 "name": "Fran\u00e7ais"
#             },
#             {
#                 "english_name": "Spanish",
#                 "iso_639_1": "es",
#                 "name": "Espa\u00f1ol"
#             }
#         ],
#         "title": "Waiting for Bojangles",
#         "vote_average": 7.4,
#         "vote_count": 298
#     },
#     {
#         "budget": 0,
#         "genres": [
#             {
#                 "id": 35,
#                 "name": "Comedy"
#             }
#         ],
#         "homepage": "http://www.magpictures.com/ilovemydad/",
#         "original_language": "en",
#         "original_title": "I Love My Dad",
#         "overview": "A hopelessly estranged father catfishes his son in an attempt to reconnect.",
#         "popularity": 13.775,
#         "production_countries": [
#             {
#                 "iso_3166_1": "US",
#                 "name": "United States of America"
#             }
#         ],
#         "release_date": "2022-08-05",
#         "revenue": 0,
#         "runtime": 90,
#         "spoken_languages": [
#             {
#                 "english_name": "English",
#                 "iso_639_1": "en",
#                 "name": "English"
#             }
#         ],
#         "title": "I Love My Dad",
#         "vote_average": 5.8,
#         "vote_count": 42
#     },
#     {
#         "budget": 0,
#         "genres": [
#             {
#                 "id": 18,
#                 "name": "Drama"
#             },
#             {
#                 "id": 10749,
#                 "name": "Romance"
#             }
#         ],
#         "homepage": "",
#         "original_language": "en",
#         "original_title": "A Love Song",
#         "overview": "Two childhood sweethearts, now both widowed, share a night by a lake in the mountains.",
#         "popularity": 12.292,
#         "production_countries": [
#             {
#                 "iso_3166_1": "US",
#                 "name": "United States of America"
#             }
#         ],
#         "release_date": "2022-07-29",
#         "revenue": 278562,
#         "runtime": 81,
#         "spoken_languages": [
#             {
#                 "english_name": "English",
#                 "iso_639_1": "en",
#                 "name": "English"
#             },
#             {
#                 "english_name": "Spanish",
#                 "iso_639_1": "es",
#                 "name": "Espa\u00f1ol"
#             }
#         ],
#         "title": "A Love Song",
#         "vote_average": 6.9,
#         "vote_count": 34
#     },
#     {
#         "budget": 0,
#         "genres": [
#             {
#                 "id": 10749,
#                 "name": "Romance"
#             },
#             {
#                 "id": 18,
#                 "name": "Drama"
#             }
#         ],
#         "homepage": "",
#         "original_language": "en",
#         "original_title": "Alone Together",
#         "overview": "Strangers June and Charlie wind up double-booked in the same upstate New York Airbnb during the start of COVID-19. Exasperating the situation, the lockdown forces them both to stay and confront the unexpected feelings that develop between them.",
#         "popularity": 15.47,
#         "production_countries": [
#             {
#                 "iso_3166_1": "US",
#                 "name": "United States of America"
#             }
#         ],
#         "release_date": "2022-07-22",
#         "revenue": 0,
#         "runtime": 101,
#         "spoken_languages": [
#             {
#                 "english_name": "English",
#                 "iso_639_1": "en",
#                 "name": "English"
#             }
#         ],
#         "title": "Alone Together",
#         "vote_average": 4.8,
#         "vote_count": 39
#     },
#     {
#         "budget": 0,
#         "genres": [
#             {
#                 "id": 10749,
#                 "name": "Romance"
#             },
#             {
#                 "id": 28,
#                 "name": "Action"
#             },
#             {
#                 "id": 18,
#                 "name": "Drama"
#             }
#         ],
#         "homepage": "https://www.netflix.com/title/81689799",
#         "original_language": "tr",
#         "original_title": "Romantik H\u0131rs\u0131z",
#         "overview": "After learning that the art thief she has been chasing is her ex-lover, an officer working for Interpol concocts a plan to catch him red-handed.",
#         "popularity": 129.277,
#         "production_countries": [
#             {
#                 "iso_3166_1": "TR",
#                 "name": "Turkey"
#             }
#         ],
#         "release_date": "2024-03-13",
#         "revenue": 0,
#         "runtime": 99,
#         "spoken_languages": [
#             {
#                 "english_name": "Turkish",
#                 "iso_639_1": "tr",
#                 "name": "T\u00fcrk\u00e7e"
#             }
#         ],
#         "title": "Art of Love",
#         "vote_average": 6.573,
#         "vote_count": 96
#     },
#     {
#         "budget": 0,
#         "genres": [
#             {
#                 "id": 28,
#                 "name": "Action"
#             },
#             {
#                 "id": 878,
#                 "name": "Science Fiction"
#             }
#         ],
#         "homepage": "https://www.thewheelmovie.com/",
#         "original_language": "en",
#         "original_title": "The Wheel",
#         "overview": "Sometime in the near future, paraplegic prison inmate Matt Mills meets \"The Board\" of Satoshi-Telefair Industries, who thank him for joining the Program. Under pressure and with a promise to make him walk again, Mills agrees to volunteer. He is injected with a synthetic nanomaterial and suffocated, only to wake up with restored use of his legs, yet alone in a steel cell in the first spoke of an experimental apparatus - The Wheel. A series of assailants inflict a multitude of damage to Mills' body and torment his mind, yet the synthetic nanomaterial not only restores his damaged organs, it re-engineers his strength. The experiment might be designed to kill, but Mills is determined to survive - and get back to his daughter before The Board finds her first.",
#         "popularity": 8.989,
#         "production_countries": [
#             {
#                 "iso_3166_1": "AU",
#                 "name": "Australia"
#             }
#         ],
#         "release_date": "2019-09-02",
#         "revenue": 0,
#         "runtime": 82,
#         "spoken_languages": [
#             {
#                 "english_name": "English",
#                 "iso_639_1": "en",
#                 "name": "English"
#             }
#         ],
#         "title": "The Wheel",
#         "vote_average": 5.0,
#         "vote_count": 13
#     },
#     {
#         "budget": 250000000,
#         "genres": [
#             {
#                 "id": 14,
#                 "name": "Fantasy"
#             },
#             {
#                 "id": 28,
#                 "name": "Action"
#             },
#             {
#                 "id": 35,
#                 "name": "Comedy"
#             }
#         ],
#         "homepage": "https://www.marvel.com/movies/thor-love-and-thunder",
#         "original_language": "en",
#         "original_title": "Thor: Love and Thunder",
#         "overview": "After his retirement is interrupted by Gorr the God Butcher, a galactic killer who seeks the extinction of the gods, Thor Odinson enlists the help of King Valkyrie, Korg, and ex-girlfriend Jane Foster, who now wields Mjolnir as the Mighty Thor. Together they embark upon a harrowing cosmic adventure to uncover the mystery of the God Butcher\u2019s vengeance and stop him before it\u2019s too late.",
#         "popularity": 134.854,
#         "production_countries": [
#             {
#                 "iso_3166_1": "US",
#                 "name": "United States of America"
#             }
#         ],
#         "release_date": "2022-07-06",
#         "revenue": 760900000,
#         "runtime": 119,
#         "spoken_languages": [
#             {
#                 "english_name": "English",
#                 "iso_639_1": "en",
#                 "name": "English"
#             }
#         ],
#         "title": "Thor: Love and Thunder",
#         "vote_average": 6.472,
#         "vote_count": 7111
#     },
#     {
#         "budget": 0,
#         "genres": [
#             {
#                 "id": 18,
#                 "name": "Drama"
#             },
#             {
#                 "id": 10749,
#                 "name": "Romance"
#             }
#         ],
#         "homepage": "https://www.bothsidesoftheblade.com/",
#         "original_language": "fr",
#         "original_title": "Avec amour et acharnement",
#         "overview": "Jean and Sara have been living together for 10 years. When they first met, Sara was living with Fran\u00e7ois, Jean\u2019s best friend and an admirer from back when he played rugby. Jean and Sara love each other. One day, Sara sees Fran\u00e7ois in the street. He does not notice her, but she is overtaken by the sensation that her life could suddenly change. Fran\u00e7ois gets back in touch with Jean. For the first time in years. He suggests they start working together again. From here on, things spiral out of control.",
#         "popularity": 13.426,
#         "production_countries": [
#             {
#                 "iso_3166_1": "FR",
#                 "name": "France"
#             }
#         ],
#         "release_date": "2022-07-08",
#         "revenue": 1747438,
#         "runtime": 117,
#         "spoken_languages": [
#             {
#                 "english_name": "French",
#                 "iso_639_1": "fr",
#                 "name": "Fran\u00e7ais"
#             }
#         ],
#         "title": "Both Sides of the Blade",
#         "vote_average": 5.494,
#         "vote_count": 78
#     },
#     {
#         "budget": 0,
#         "genres": [
#             {
#                 "id": 99,
#                 "name": "Documentary"
#             }
#         ],
#         "homepage": "https://films.nationalgeographic.com/fire-of-love",
#         "original_language": "en",
#         "original_title": "Fire of Love",
#         "overview": "A doomed love triangle between intrepid French scientists Katia and Maurice Krafft, and their beloved volcanoes.",
#         "popularity": 12.796,
#         "production_countries": [
#             {
#                 "iso_3166_1": "CA",
#                 "name": "Canada"
#             },
#             {
#                 "iso_3166_1": "US",
#                 "name": "United States of America"
#             }
#         ],
#         "release_date": "2022-07-06",
#         "revenue": 0,
#         "runtime": 93,
#         "spoken_languages": [
#             {
#                 "english_name": "English",
#                 "iso_639_1": "en",
#                 "name": "English"
#             },
#             {
#                 "english_name": "French",
#                 "iso_639_1": "fr",
#                 "name": "Fran\u00e7ais"
#             },
#             {
#                 "english_name": "Spanish",
#                 "iso_639_1": "es",
#                 "name": "Espa\u00f1ol"
#             },
#             {
#                 "english_name": "Portuguese",
#                 "iso_639_1": "pt",
#                 "name": "Portugu\u00eas"
#             }
#         ],
#         "title": "Fire of Love",
#         "vote_average": 7.5,
#         "vote_count": 182
#     },
#     {
#         "budget": 0,
#         "genres": [
#             {
#                 "id": 10749,
#                 "name": "Romance"
#             },
#             {
#                 "id": 35,
#                 "name": "Comedy"
#             }
#         ],
#         "homepage": "",
#         "original_language": "es",
#         "original_title": "Pared con pared",
#         "overview": "She\u2019s a young pianist preparing for an audition. He is a games inventor who can only concentrate in complete silence. Separated by only a paper-thin wall in conjoined apartments, will they learn to live in harmony with one another? Will romance blossom through the wall?",
#         "popularity": 176.179,
#         "production_countries": [
#             {
#                 "iso_3166_1": "ES",
#                 "name": "Spain"
#             }
#         ],
#         "release_date": "2024-04-12",
#         "revenue": 0,
#         "runtime": 98,
#         "spoken_languages": [
#             {
#                 "english_name": "Spanish",
#                 "iso_639_1": "es",
#                 "name": "Espa\u00f1ol"
#             }
#         ],
#         "title": "Love & Gelato",
#         "vote_average": 6.7,
#         "vote_count": 94
#     },
#     {
#         "budget": 0,
#         "genres": [
#             {
#                 "id": 99,
#                 "name": "Documentary"
#             }
#         ],
#         "homepage": "",
#         "original_language": "en",
#         "original_title": "Stay Prayed Up",
#         "overview": "Lena Mae \u201cMother\u201d Perry, the backbone of her community, cooks for crowds, tends to the needy, and boy, can she sing! After 50 years leading the dynamic, down-home gospel group The Branchettes, the octogenarian powerhouse, armed with her unwavering faith, shows no signs of slowing down. Taking us inside her loving community while following the recording of the group\u2019s first album, this film is bursting with warmth, joy, and soul-stirring gospel music.",
#         "popularity": 0.6,
#         "production_countries": [
#             {
#                 "iso_3166_1": "US",
#                 "name": "United States of America"
#             }
#         ],
#         "release_date": "2021-09-01",
#         "revenue": 0,
#         "runtime": 73,
#         "spoken_languages": [
#             {
#                 "english_name": "English",
#                 "iso_639_1": "en",
#                 "name": "English"
#             }
#         ],
#         "title": "Stay Prayed Up",
#         "vote_average": 0.0,
#         "vote_count": 0
#     },
#     {
#         "budget": 0,
#         "genres": [
#             {
#                 "id": 18,
#                 "name": "Drama"
#             },
#             {
#                 "id": 36,
#                 "name": "History"
#             },
#             {
#                 "id": 10752,
#                 "name": "War"
#             }
#         ],
#         "homepage": "",
#         "original_language": "en",
#         "original_title": "Benediction",
#         "overview": "Poet Siegfried Sassoon survived the horrors of fighting in the First World War and was decorated for his bravery, but became a vocal critic of the government's continuation of the war when he returned from service. Adored by members of the aristocracy as well as stars of London's literary and stage world, he embarked on affairs with several men as he attempted to come to terms with his homosexuality.",
#         "popularity": 17.748,
#         "production_countries": [
#             {
#                 "iso_3166_1": "GB",
#                 "name": "United Kingdom"
#             },
#             {
#                 "iso_3166_1": "US",
#                 "name": "United States of America"
#             }
#         ],
#         "release_date": "2021-12-23",
#         "revenue": 847418,
#         "runtime": 137,
#         "spoken_languages": [
#             {
#                 "english_name": "English",
#                 "iso_639_1": "en",
#                 "name": "English"
#             },
#             {
#                 "english_name": "French",
#                 "iso_639_1": "fr",
#                 "name": "Fran\u00e7ais"
#             },
#             {
#                 "english_name": "German",
#                 "iso_639_1": "de",
#                 "name": "Deutsch"
#             }
#         ],
#         "title": "Benediction",
#         "vote_average": 6.13,
#         "vote_count": 54
#     },
#     {
#         "budget": 0,
#         "genres": [
#             {
#                 "id": 10749,
#                 "name": "Romance"
#             },
#             {
#                 "id": 35,
#                 "name": "Comedy"
#             },
#             {
#                 "id": 10402,
#                 "name": "Music"
#             }
#         ],
#         "homepage": "https://www.dinnerinamerica.com",
#         "original_language": "en",
#         "original_title": "Dinner in America",
#         "overview": "An on-the-lam punk rocker and a young woman obsessed with his band go on an unexpected and epic journey together through the decaying suburbs of the American Midwest.",
#         "popularity": 12.293,
#         "production_countries": [
#             {
#                 "iso_3166_1": "US",
#                 "name": "United States of America"
#             }
#         ],
#         "release_date": "2022-05-27",
#         "revenue": 0,
#         "runtime": 106,
#         "spoken_languages": [
#             {
#                 "english_name": "English",
#                 "iso_639_1": "en",
#                 "name": "English"
#             }
#         ],
#         "title": "Dinner in America",
#         "vote_average": 7.281,
#         "vote_count": 48
#     },
#     {
#         "budget": 0,
#         "genres": [
#             {
#                 "id": 18,
#                 "name": "Drama"
#             }
#         ],
#         "homepage": "",
#         "original_language": "en",
#         "original_title": "In a New York Minute",
#         "overview": "In A New York Minute follows three Asian women, each at a different stage in their life as they deal with their own personal struggles. Amy is haunted by a past breakup that has manifested into an eating disorder. Angel is caught between a loveless marriage with an older American businessman and a passionate affair with Chinese filmmaker. Nina moonlights as an escort as a way of supporting herself financially. As the story unfolds, the film reveals each character\u2019s wants and desires is reflected in the other.",
#         "popularity": 3.612,
#         "production_countries": [],
#         "release_date": "2019-04-28",
#         "revenue": 0,
#         "runtime": 102,
#         "spoken_languages": [
#             {
#                 "english_name": "English",
#                 "iso_639_1": "en",
#                 "name": "English"
#             }
#         ],
#         "title": "In a New York Minute",
#         "vote_average": 3.2,
#         "vote_count": 2
#     },
#     {
#         "budget": 0,
#         "genres": [
#             {
#                 "id": 18,
#                 "name": "Drama"
#             },
#             {
#                 "id": 10749,
#                 "name": "Romance"
#             },
#             {
#                 "id": 35,
#                 "name": "Comedy"
#             }
#         ],
#         "homepage": "",
#         "original_language": "fr",
#         "original_title": "Les Amours d\u2019Ana\u00efs",
#         "overview": "A young woman struggling to stay on top of everything in her life meets a married publisher and begins an affair with him.",
#         "popularity": 13.076,
#         "production_countries": [
#             {
#                 "iso_3166_1": "FR",
#                 "name": "France"
#             }
#         ],
#         "release_date": "2021-09-15",
#         "revenue": 41356,
#         "runtime": 98,
#         "spoken_languages": [
#             {
#                 "english_name": "French",
#                 "iso_639_1": "fr",
#                 "name": "Fran\u00e7ais"
#             },
#             {
#                 "english_name": "English",
#                 "iso_639_1": "en",
#                 "name": "English"
#             }
#         ],
#         "title": "Ana\u00efs in Love",
#         "vote_average": 6.237,
#         "vote_count": 137
#     },
#     {
#         "budget": 0,
#         "genres": [
#             {
#                 "id": 35,
#                 "name": "Comedy"
#             },
#             {
#                 "id": 10749,
#                 "name": "Romance"
#             }
#         ],
#         "homepage": "",
#         "original_language": "fr",
#         "original_title": "I Love America",
#         "overview": "A single woman who decides to take a chance on love again by catapulting her life from Paris to Los Angeles. From awkward dates to touching surprise encounters, she understands the journey to love is a journey towards herself.",
#         "popularity": 8.05,
#         "production_countries": [
#             {
#                 "iso_3166_1": "US",
#                 "name": "United States of America"
#             },
#             {
#                 "iso_3166_1": "FR",
#                 "name": "France"
#             }
#         ],
#         "release_date": "2022-03-11",
#         "revenue": 0,
#         "runtime": 102,
#         "spoken_languages": [
#             {
#                 "english_name": "French",
#                 "iso_639_1": "fr",
#                 "name": "Fran\u00e7ais"
#             },
#             {
#                 "english_name": "English",
#                 "iso_639_1": "en",
#                 "name": "English"
#             },
#             {
#                 "english_name": "Spanish",
#                 "iso_639_1": "es",
#                 "name": "Espa\u00f1ol"
#             }
#         ],
#         "title": "I Love America",
#         "vote_average": 5.0,
#         "vote_count": 73
#     },
#     {
#         "budget": 0,
#         "genres": [
#             {
#                 "id": 18,
#                 "name": "Drama"
#             }
#         ],
#         "homepage": "https://vanishingangle.com/see-you-then",
#         "original_language": "en",
#         "original_title": "See You Then",
#         "overview": "A decade after abruptly breaking up with Naomi, Kris invites her to a dinner to catch-up on their complicated lives, relationships, and Kris' transition.",
#         "popularity": 1.232,
#         "production_countries": [
#             {
#                 "iso_3166_1": "US",
#                 "name": "United States of America"
#             }
#         ],
#         "release_date": "2022-04-01",
#         "revenue": 0,
#         "runtime": 74,
#         "spoken_languages": [
#             {
#                 "english_name": "English",
#                 "iso_639_1": "en",
#                 "name": "English"
#             }
#         ],
#         "title": "See You Then",
#         "vote_average": 1.8,
#         "vote_count": 3
#     },
#     {
#         "budget": 0,
#         "genres": [
#             {
#                 "id": 99,
#                 "name": "Documentary"
#             }
#         ],
#         "homepage": "http://gadeafilms.com/la-mami",
#         "original_language": "es",
#         "original_title": "La Mami",
#         "overview": "One of the rooms inside the legendary Barba Azul Cabaret has become a shelter for the girls working there: the women's bathroom. Every night La Mami, who's in charge of the bathrooms, offers them the warmth and the advice they need to take on the challenge they face in the dance hall.",
#         "popularity": 2.206,
#         "production_countries": [
#             {
#                 "iso_3166_1": "MX",
#                 "name": "Mexico"
#             },
#             {
#                 "iso_3166_1": "ES",
#                 "name": "Spain"
#             }
#         ],
#         "release_date": "2020-01-27",
#         "revenue": 0,
#         "runtime": 82,
#         "spoken_languages": [
#             {
#                 "english_name": "Spanish",
#                 "iso_639_1": "es",
#                 "name": "Espa\u00f1ol"
#             }
#         ],
#         "title": "La Mami",
#         "vote_average": 6.2,
#         "vote_count": 4
#     },
#     {
#         "budget": 0,
#         "genres": [
#             {
#                 "id": 18,
#                 "name": "Drama"
#             }
#         ],
#         "homepage": "",
#         "original_language": "zh",
#         "original_title": "\u7b2c\u4e00\u7089\u9999",
#         "overview": "The film tells the story of a young girl who travels from Shanghai to Hong Kong in pursuit of education, but ends up working for her aunt seducing rich and powerful men.",
#         "popularity": 3.842,
#         "production_countries": [
#             {
#                 "iso_3166_1": "CN",
#                 "name": "China"
#             }
#         ],
#         "release_date": "2021-10-22",
#         "revenue": 0,
#         "runtime": 144,
#         "spoken_languages": [
#             {
#                 "english_name": "Mandarin",
#                 "iso_639_1": "zh",
#                 "name": "\u666e\u901a\u8bdd"
#             }
#         ],
#         "title": "Love After Love",
#         "vote_average": 5.6,
#         "vote_count": 25
#     },
#     {
#         "budget": 49000000,
#         "genres": [
#             {
#                 "id": 18,
#                 "name": "Drama"
#             },
#             {
#                 "id": 9648,
#                 "name": "Mystery"
#             },
#             {
#                 "id": 53,
#                 "name": "Thriller"
#             }
#         ],
#         "homepage": "https://www.hulu.com/movie/deep-water-2c4ae82e-2c1b-41d5-a651-82189d1c8b2c",
#         "original_language": "en",
#         "original_title": "Deep Water",
#         "overview": "Vic and Melinda Van Allen are a couple in the small town of Little Wesley. Their loveless marriage is held together only by a precarious arrangement whereby, in order to avoid the messiness of divorce, Melinda is allowed to take any number of lovers as long as she does not desert her family.",
#         "popularity": 129.229,
#         "production_countries": [
#             {
#                 "iso_3166_1": "US",
#                 "name": "United States of America"
#             }
#         ],
#         "release_date": "2022-03-18",
#         "revenue": 0,
#         "runtime": 116,
#         "spoken_languages": [
#             {
#                 "english_name": "English",
#                 "iso_639_1": "en",
#                 "name": "English"
#             }
#         ],
#         "title": "Deep Water",
#         "vote_average": 5.79,
#         "vote_count": 1261
#     },
#     {
#         "budget": 0,
#         "genres": [
#             {
#                 "id": 99,
#                 "name": "Documentary"
#             }
#         ],
#         "homepage": "https://www.amazon.com/dp/B09QG6H8D9",
#         "original_language": "en",
#         "original_title": "Lucy and Desi",
#         "overview": "Explore the unlikely partnership and enduring legacy of one of the most prolific power couples in entertainment history. Lucille Ball and Desi Arnaz risked everything to be together.",
#         "popularity": 13.415,
#         "production_countries": [
#             {
#                 "iso_3166_1": "US",
#                 "name": "United States of America"
#             }
#         ],
#         "release_date": "2022-01-21",
#         "revenue": 0,
#         "runtime": 102,
#         "spoken_languages": [
#             {
#                 "english_name": "English",
#                 "iso_639_1": "en",
#                 "name": "English"
#             }
#         ],
#         "title": "Lucy and Desi",
#         "vote_average": 7.1,
#         "vote_count": 37
#     },
#     {
#         "budget": 20000000,
#         "genres": [
#             {
#                 "id": 18,
#                 "name": "Drama"
#             },
#             {
#                 "id": 10749,
#                 "name": "Romance"
#             }
#         ],
#         "homepage": "https://www.unitedartistsreleasing.com/cyrano/synopsis/",
#         "original_language": "en",
#         "original_title": "Cyrano",
#         "overview": "A man ahead of his time, Cyrano de Bergerac dazzles whether with ferocious wordplay at a verbal joust or with brilliant swordplay in a duel. But, convinced that his appearance renders him unworthy of the love of a devoted friend, the luminous Roxanne, Cyrano has yet to declare his feelings for her\u2014and Roxanne has fallen in love, at first sight, with Christian.",
#         "popularity": 24.292,
#         "production_countries": [
#             {
#                 "iso_3166_1": "CA",
#                 "name": "Canada"
#             },
#             {
#                 "iso_3166_1": "GB",
#                 "name": "United Kingdom"
#             },
#             {
#                 "iso_3166_1": "US",
#                 "name": "United States of America"
#             }
#         ],
#         "release_date": "2021-12-17",
#         "revenue": 3000000,
#         "runtime": 124,
#         "spoken_languages": [
#             {
#                 "english_name": "English",
#                 "iso_639_1": "en",
#                 "name": "English"
#             }
#         ],
#         "title": "Cyrano",
#         "vote_average": 6.424,
#         "vote_count": 269
#     },
#     {
#         "budget": 0,
#         "genres": [
#             {
#                 "id": 10749,
#                 "name": "Romance"
#             },
#             {
#                 "id": 878,
#                 "name": "Science Fiction"
#             },
#             {
#                 "id": 18,
#                 "name": "Drama"
#             }
#         ],
#         "homepage": "https://www.netflix.com/title/81447264",
#         "original_language": "en",
#         "original_title": "The In Between",
#         "overview": "After surviving a car accident that took the life of her boyfriend, a teenage girl believes he's attempting to reconnect with her from the after world.",
#         "popularity": 25.935,
#         "production_countries": [
#             {
#                 "iso_3166_1": "US",
#                 "name": "United States of America"
#             }
#         ],
#         "release_date": "2022-02-11",
#         "revenue": 0,
#         "runtime": 116,
#         "spoken_languages": [
#             {
#                 "english_name": "English",
#                 "iso_639_1": "en",
#                 "name": "English"
#             }
#         ],
#         "title": "The In Between",
#         "vote_average": 7.363,
#         "vote_count": 677
#     },
#     {
#         "budget": 0,
#         "genres": [
#             {
#                 "id": 35,
#                 "name": "Comedy"
#             },
#             {
#                 "id": 10749,
#                 "name": "Romance"
#             },
#             {
#                 "id": 18,
#                 "name": "Drama"
#             }
#         ],
#         "homepage": "",
#         "original_language": "en",
#         "original_title": "Book of Love",
#         "overview": "Henry, an English writer who has written a new book that has become a failure in the U.K, gets notified that the dull book has been highly trending over in Mexico. Little does he know that Maria, a Spanish translator, turned the book into an erotic novel. Henry and Maria then swerve around Mexico to do a book tour and go through a wind of events.",
#         "popularity": 13.518,
#         "production_countries": [
#             {
#                 "iso_3166_1": "MX",
#                 "name": "Mexico"
#             },
#             {
#                 "iso_3166_1": "GB",
#                 "name": "United Kingdom"
#             },
#             {
#                 "iso_3166_1": "US",
#                 "name": "United States of America"
#             }
#         ],
#         "release_date": "2022-01-06",
#         "revenue": 398876,
#         "runtime": 106,
#         "spoken_languages": [
#             {
#                 "english_name": "English",
#                 "iso_639_1": "en",
#                 "name": "English"
#             },
#             {
#                 "english_name": "Spanish",
#                 "iso_639_1": "es",
#                 "name": "Espa\u00f1ol"
#             },
#             {
#                 "english_name": "Portuguese",
#                 "iso_639_1": "pt",
#                 "name": "Portugu\u00eas"
#             }
#         ],
#         "title": "Book of Love",
#         "vote_average": 5.6,
#         "vote_count": 116
#     },
#     {
#         "budget": 0,
#         "genres": [
#             {
#                 "id": 18,
#                 "name": "Drama"
#             }
#         ],
#         "homepage": "",
#         "original_language": "fr",
#         "original_title": "Lingui : les liens sacr\u00e9s",
#         "overview": "On the outskirts of the capital of Chad, determined single mother Amina works tirelessly to provide for herself and her 15-year old daughter Maria. When Amina discovers Maria is pregnant and does not want a child, the two women begin to seek out an abortion, condemned by both religion and law. In the process, mother and daughter forge a connection stronger than any they\u2019ve ever known.",
#         "popularity": 5.383,
#         "production_countries": [
#             {
#                 "iso_3166_1": "DE",
#                 "name": "Germany"
#             },
#             {
#                 "iso_3166_1": "BE",
#                 "name": "Belgium"
#             },
#             {
#                 "iso_3166_1": "TD",
#                 "name": "Chad"
#             },
#             {
#                 "iso_3166_1": "FR",
#                 "name": "France"
#             }
#         ],
#         "release_date": "2021-12-08",
#         "revenue": 0,
#         "runtime": 88,
#         "spoken_languages": [
#             {
#                 "english_name": "Arabic",
#                 "iso_639_1": "ar",
#                 "name": "\u0627\u0644\u0639\u0631\u0628\u064a\u0629"
#             },
#             {
#                 "english_name": "French",
# ...
#                 "name": "Fran\u00e7ais"
#             }
#         ],
#         "title": "Lost in Paris",
#         "vote_average": 6.0,
#         "vote_count": 113
#     },
#     {
#         "budget": 5000000,
#         "genres": [
#             {
#                 "id": 18,
#                 "name": "Drama"
#             },
#             {
#                 "id": 80,
#                 "name": "Crime"
#             },
#             {
#                 "id": 53,
#                 "name": "Thriller"
#             }
#         ],
#         "homepage": "",
#         "original_language": "en",
#         "original_title": "Vincent N Roxxy",
#         "overview": "A small town loner and a rebellious punk rocker unexpectedly fall in love as they are forced on the run and soon discover violence follows them everywhere.",
#         "popularity": 13.935,
#         "production_countries": [
#             {
#                 "iso_3166_1": "US",
#                 "name": "United States of America"
#             }
#         ],
#         "release_date": "2016-04-18",
#         "revenue": 0,
#         "runtime": 110,
#         "spoken_languages": [
#             {
#                 "english_name": "English",
#                 "iso_639_1": "en",
#                 "name": "English"
#             }
#         ],
#         "title": "Vincent N Roxxy,",
#         "vote_average": 5.4,
#         "vote_count": 88
#     },
#     {
#         "budget": 10000000,
#         "genres": [
#             {
#                 "id": 18,
#                 "name": "Drama"
#             },
#             {
#                 "id": 10749,
#                 "name": "Romance"
#             }
#         ],
#         "homepage": "http://everythingeverythingmovie.com",
#         "original_language": "en",
#         "original_title": "Everything, Everything",
#         "overview": "A teenager who's lived a sheltered life because she's allergic to everything, falls for the boy who moves in next door.",
#         "popularity": 33.539,
#         "production_countries": [
#             {
#                 "iso_3166_1": "US",
#                 "name": "United States of America"
#             }
#         ],
#         "release_date": "2017-05-18",
#         "revenue": 61621140,
#         "runtime": 96,
#         "spoken_languages": [
#             {
#                 "english_name": "English",
#                 "iso_639_1": "en",
#                 "name": "English"
#             }
#         ],
#         "title": "Everything, Everything",
#         "vote_average": 7.247,
#         "vote_count": 3632
#     },
#     {
#         "budget": 0,
#         "genres": [
#             {
#                 "id": 80,
#                 "name": "Crime"
#             },
#             {
#                 "id": 18,
#                 "name": "Drama"
#             },
#             {
#                 "id": 27,
#                 "name": "Horror"
#             }
#         ],
#         "homepage": "http://www.houndsoflovemovie.com/",
#         "original_language": "en",
#         "original_title": "Hounds of Love",
#         "overview": "When Vicki Maloney is randomly abducted from a suburban street by a disturbed couple, she soon observes the dynamic between her captors and quickly realises she must drive a wedge between them if she is to survive.",
#         "popularity": 22.38,
#         "production_countries": [
#             {
#                 "iso_3166_1": "AU",
#                 "name": "Australia"
#             }
#         ],
#         "release_date": "2016-10-07",
#         "revenue": 0,
#         "runtime": 108,
#         "spoken_languages": [
#             {
#                 "english_name": "English",
#                 "iso_639_1": "en",
#                 "name": "English"
#             }
#         ],
#         "title": "Hounds of Love",
#         "vote_average": 6.1,
#         "vote_count": 326
#     },
#     {
#         "budget": 0,
#         "genres": [
#             {
#                 "id": 99,
#                 "name": "Documentary"
#             }
#         ],
#         "homepage": "http://haroldandlillian.com",
#         "original_language": "en",
#         "original_title": "Harold and Lillian: A Hollywood Love Story",
#         "overview": "Working largely uncredited in the Hollywood system, storyboard artist Harold and film researcher Lillian left an indelible mark on classics by Alfred Hitchcock, Steven Spielberg, Mel Brooks, Stanley Kubrick, Roman Polanski and many more.",
#         "popularity": 3.79,
#         "production_countries": [
#             {
#                 "iso_3166_1": "US",
#                 "name": "United States of America"
#             }
#         ],
#         "release_date": "2017-02-01",
#         "revenue": 0,
#         "runtime": 96,
#         "spoken_languages": [
#             {
#                 "english_name": "English",
#                 "iso_639_1": "en",
#                 "name": "English"
#             }
#         ],
#         "title": "Harold and Lillian",
#         "vote_average": 6.8,
#         "vote_count": 19
#     },
#     {
#         "budget": 1330000,
#         "genres": [
#             {
#                 "id": 18,
#                 "name": "Drama"
#             },
#             {
#                 "id": 10749,
#                 "name": "Romance"
#             }
#         ],
#         "homepage": "",
#         "original_language": "fi",
#         "original_title": "Hymyilev\u00e4 mies",
#         "overview": "Summer 1962 and Olli M\u00e4ki has a shot at the world championship title in featherweight boxing. From the Finnish countryside to the bright lights of Helsinki, everything has been prepared for his fame and fortune. All Olli has to do is lose weight and concentrate. But there is a problem \u2013 he has fallen in love with Raija.",
#         "popularity": 16.896,
#         "production_countries": [
#             {
#                 "iso_3166_1": "FI",
#                 "name": "Finland"
#             },
#             {
#                 "iso_3166_1": "DE",
#                 "name": "Germany"
#             },
#             {
#                 "iso_3166_1": "SE",
#                 "name": "Sweden"
#             }
#         ],
#         "release_date": "2016-09-02",
#         "revenue": 0,
#         "runtime": 95,
#         "spoken_languages": [
#             {
#                 "english_name": "English",
#                 "iso_639_1": "en",
#                 "name": "English"
#             },
#             {
#                 "english_name": "Finnish",
#                 "iso_639_1": "fi",
#                 "name": "suomi"
#             }
#         ],
#         "title": "The Happiest Day in the Life of Olli Maki,",
#         "vote_average": 6.7,
#         "vote_count": 82
#     },
#     {
#         "budget": 90000000,
#         "genres": [
#             {
#                 "id": 36,
#                 "name": "History"
#             },
#             {
#                 "id": 10749,
#                 "name": "Romance"
#             },
#             {
#                 "id": 18,
#                 "name": "Drama"
#             }
#         ],
#         "homepage": "http://www.survivalpictures.org/the-promise/",
#         "original_language": "en",
#         "original_title": "The Promise",
#         "overview": "Set during the last days of the Ottoman Empire, a love triangle develops between Mikael, a brilliant medical student, the beautiful and sophisticated artist Ana, and Chris, a renowned American journalist based in Paris.",
#         "popularity": 32.378,
#         "production_countries": [
#             {
#                 "iso_3166_1": "ES",
#                 "name": "Spain"
#             },
#             {
#                 "iso_3166_1": "US",
#                 "name": "United States of America"
#             }
#         ],
#         "release_date": "2016-12-02",
#         "revenue": 12448676,
#         "runtime": 133,
#         "spoken_languages": [
#             {
#                 "english_name": "Armenian",
#                 "iso_639_1": "hy",
#                 "name": ""
#             },
#             {
#                 "english_name": "German",
#                 "iso_639_1": "de",
#                 "name": "Deutsch"
#             },
#             {
#                 "english_name": "English",
#                 "iso_639_1": "en",
#                 "name": "English"
#             },
#             {
#                 "english_name": "French",
#                 "iso_639_1": "fr",
#                 "name": "Fran\u00e7ais"
#             }
#         ],
#         "title": "The Promise",
#         "vote_average": 6.9,
#         "vote_count": 449
#     },
#     {
#         "budget": 0,
#         "genres": [
#             {
#                 "id": 36,
#                 "name": "History"
#             },
#             {
#                 "id": 18,
#                 "name": "Drama"
#             },
#             {
#                 "id": 10749,
#                 "name": "Romance"
#             }
#         ],
#         "homepage": "",
#         "original_language": "fr",
#         "original_title": "Frantz",
#         "overview": "In the aftermath of WWI, a young German who grieves the death of her fianc\u00e9 in France meets a mysterious French man who visits the fiance\u2019s grave to lay flowers.",
#         "popularity": 20.292,
#         "production_countries": [
#             {
#                 "iso_3166_1": "FR",
#                 "name": "France"
#             },
#             {
#                 "iso_3166_1": "DE",
#                 "name": "Germany"
#             }
#         ],
#         "release_date": "2016-09-07",
#         "revenue": 7478354,
#         "runtime": 113,
#         "spoken_languages": [
#             {
#                 "english_name": "German",
#                 "iso_639_1": "de",
#                 "name": "Deutsch"
#             },
#             {
#                 "english_name": "French",
#                 "iso_639_1": "fr",
#                 "name": "Fran\u00e7ais"
#             }
#         ],
#         "title": "Frantz,",
#         "vote_average": 7.36,
#         "vote_count": 666
#     },
#     {
#         "budget": 0,
#         "genres": [
#             {
#                 "id": 18,
#                 "name": "Drama"
#             },
#             {
#                 "id": 10749,
#                 "name": "Romance"
#             }
#         ],
#         "homepage": "http://theotherhalfmovie.com/",
#         "original_language": "en",
#         "original_title": "The Other Half",
#         "overview": "A grief-stricken man and a bipolar woman fall in love and attempt to forge a simple life together.",
#         "popularity": 5.596,
#         "production_countries": [
#             {
#                 "iso_3166_1": "CA",
#                 "name": "Canada"
#             }
#         ],
#         "release_date": "2016-12-02",
#         "revenue": 0,
#         "runtime": 103,
#         "spoken_languages": [
#             {
#                 "english_name": "English",
#                 "iso_639_1": "en",
#                 "name": "English"
#             }
#         ],
#         "title": "The Other Half",
#         "vote_average": 6.3,
#         "vote_count": 24
#     },
#     {
#         "budget": 40000000,
#         "genres": [
#             {
#                 "id": 10749,
#                 "name": "Romance"
#             },
#             {
#                 "id": 18,
#                 "name": "Drama"
#             },
#             {
#                 "id": 10752,
#                 "name": "War"
#             }
#         ],
#         "homepage": "https://www.uphe.com/movies/the-ottoman-lieutenant",
#         "original_language": "en",
#         "original_title": "The Ottoman Lieutenant",
#         "overview": "Lillie, a determined American woman, ventures overseas to join Dr. Jude at a remote medical mission in the Ottoman Empire (now Turkey). However, Lillie soon finds herself at odds with Jude and the mission\u2019s founder, Woodruff, when she falls for the titular military man, Ismail, just as the war is about to erupt.",
#         "popularity": 15.217,
#         "production_countries": [
#             {
#                 "iso_3166_1": "TR",
#                 "name": "Turkey"
#             },
#             {
#                 "iso_3166_1": "US",
#                 "name": "United States of America"
#             }
#         ],
#         "release_date": "2017-03-10",
#         "revenue": 413844,
#         "runtime": 111,
#         "spoken_languages": [
#             {
#                 "english_name": "Turkish",
#                 "iso_639_1": "tr",
#                 "name": "T\u00fcrk\u00e7e"
#             },
#             {
#                 "english_name": "English",
#                 "iso_639_1": "en",
#                 "name": "English"
#             }
#         ],
#         "title": "The Ottoman Lieutenant",
#         "vote_average": 6.173,
#         "vote_count": 246
#     },
#     {
#         "budget": 0,
#         "genres": [
#             {
#                 "id": 10749,
#                 "name": "Romance"
#             },
#             {
#                 "id": 35,
#                 "name": "Comedy"
#             }
#         ],
#         "homepage": "",
#         "original_language": "es",
#         "original_title": "Pared con pared",
#         "overview": "She\u2019s a young pianist preparing for an audition. He is a games inventor who can only concentrate in complete silence. Separated by only a paper-thin wall in conjoined apartments, will they learn to live in harmony with one another? Will romance blossom through the wall?",
#         "popularity": 176.179,
#         "production_countries": [
#             {
#                 "iso_3166_1": "ES",
#                 "name": "Spain"
#             }
#         ],
#         "release_date": "2024-04-12",
#         "revenue": 0,
#         "runtime": 98,
#         "spoken_languages": [
#             {
#                 "english_name": "Spanish",
#                 "iso_639_1": "es",
#                 "name": "Espa\u00f1ol"
#             }
#         ],
#         "title": "Love & Taxes",
#         "vote_average": 6.7,
#         "vote_count": 94
#     },
#     {
#         "budget": 2000000,
#         "genres": [
#             {
#                 "id": 10749,
#                 "name": "Romance"
#             },
#             {
#                 "id": 35,
#                 "name": "Comedy"
#             }
#         ],
#         "homepage": "",
#         "original_language": "en",
#         "original_title": "Everybody Loves Somebody",
#         "overview": "On the surface, Clara Barron seems to have it all: a job as an OB-GYN; a great house in LA; and a loving family. But, the one thing Clara doesn't have figured out is her love life. Pressured by a family wedding in Mexico, Clara asks a co-worker to pose as her boyfriend for the weekend festivities,- only to be caught by surprise when her ex- boyfriend (and family favorite) suddenly shows up after disappearing from her life completely. Torn, Clara must decide between going back to the past or open her heart to new and unexpected possibilities.",
#         "popularity": 12.306,
#         "production_countries": [
#             {
#                 "iso_3166_1": "MX",
#                 "name": "Mexico"
#             }
#         ],
#         "release_date": "2017-02-10",
#         "revenue": 0,
#         "runtime": 102,
#         "spoken_languages": [
#             {
#                 "english_name": "English",
#                 "iso_639_1": "en",
#                 "name": "English"
#             },
#             {
#                 "english_name": "Spanish",
#                 "iso_639_1": "es",
#                 "name": "Espa\u00f1ol"
#             }
#         ],
#         "title": "Everybody Loves Somebody,",
#         "vote_average": 6.6,
#         "vote_count": 158
#     },
#     {
#         "budget": 0,
#         "genres": [
#             {
#                 "id": 10749,
#                 "name": "Romance"
#             }
#         ],
#         "homepage": "",
#         "original_language": "ta",
#         "original_title": "\u0b95\u0bc7\u0b9f\u0bbf",
#         "overview": "A happy-go-lucky student at a university gets embroiled in a love triangle with two very different young women.",
#         "popularity": 5.683,
#         "production_countries": [
#             {
#                 "iso_3166_1": "IN",
#                 "name": "India"
#             }
#         ],
#         "release_date": "2006-09-24",
#         "revenue": 0,
#         "runtime": 189,
#         "spoken_languages": [
#             {
#                 "english_name": "Tamil",
#                 "iso_639_1": "ta",
#                 "name": "\u0ba4\u0bae\u0bbf\u0bb4\u0bcd"
#             }
#         ],
#         "title": "Kedi,",
#         "vote_average": 4.0,
#         "vote_count": 2
#     }
# ]

# %%
# Convert the results to a DataFrame
tmdb_df = pd.DataFrame(tmdb_movies_list)

#df_tmdb_df.head()
tmdb_df.shape
# Out:
# (186, 15)

# %% [markdown]
# ### Merge and Clean the Data for Export

# %%
# Merge the New York Times reviews and TMDB DataFrames on title
grouped_df = tmdb_df.merge(df, how='inner', left_on='title', right_on='Title')
grouped_df.head()
# Out:
#                   title        original_title  budget original_language  \
# 0  Pamela, a Love Story  Pamela, A Love Story       0                en
# 1      In From the Side      In from the Side       0                en
# 2            After Love            After Love       0                en
# 3            After Love            After Love       0                en
# 4              Alcarràs              Alcarràs       0                ca
#
#                                  homepage  \
# 0  https://www.netflix.com/title/81590934
# 1       http://www.infromthesidemovie.com
# 2
# 3
# 4          https://www.alcarras-film.com/
#
#                                             overview  popularity  runtime  \
# 0  In her own words, through personal video and d...      17.091      113
# 1  Mark, a new and inexperienced rugby club membe...      14.059      134
# 2  Set in the port town of Dover in the South-Eas...      15.106       89
# 3  Set in the port town of Dover in the South-Eas...      15.106       89
# 4  In a small village in Catalonia, the peach far...      11.358      120
#
#    revenue release_date  ...  headline.kicker  headline.content_kicker  \
# 0        0   2023-01-30  ...             None                     None
# 1        0   2022-09-16  ...             None                     None
# 2        0   2021-06-04  ...    Critic’s Pick                     None
# 3        0   2021-06-04  ...             None                     None
# 4        0   2022-04-29  ...             None                     None
#
#   headline.print_headline headline.name headline.seo headline.sub  \
# 0    Pamela, a Love Story          None         None         None
# 1        In From the Side          None         None         None
# 2              After Love          None         None         None
# 3              After Love          None         None         None
# 4                Alcarràs          None         None         None
#
#       byline.original                                      byline.person  \
# 0      By Glenn Kenny  [{'firstname': 'Glenn', 'middlename': None, 'l...
# 1      By Kyle Turner  [{'firstname': 'Kyle', 'middlename': None, 'la...
# 2  By Beatrice Loayza  [{'firstname': 'Beatrice', 'middlename': None,...
# 3      By Glenn Kenny  [{'firstname': 'Glenn', 'middlename': None, 'l...
# 4    By Devika Girish  [{'firstname': 'Devika', 'middlename': None, '...
#
#   byline.organization                 Title
# 0                None  Pamela, a Love Story
# 1                None      In From the Side
# 2                None            After Love
# 3                None            After Love
# 4                None              Alcarràs
#
# [5 rows x 32 columns]

# %%
# Remove list brackets and quotation marks on the columns containing lists
# Create a list of the columns that need fixing
columns_to_fix = ['byline.person','genres', 'spoken_languages','production_countries',]

# Create a list of characters to remove
characters_to_remove = ['[',']',"'"]

# Loop through the list of columns to fix
for col in columns_to_fix:

    # Convert the column to type 'str'
    grouped_df[col] = grouped_df[col].astype(str)

    # Loop through characters to remove
    for s in characters_to_remove:
        grouped_df[col] = grouped_df[col].str.replace(s,'')

# Display the fixed DataFrame
grouped_df[columns_to_fix].head()
# Out:
#                                        byline.person  \
# 0  {firstname: Glenn, middlename: None, lastname:...
# 1  {firstname: Kyle, middlename: None, lastname: ...
# 2  {firstname: Beatrice, middlename: None, lastna...
# 3  {firstname: Glenn, middlename: None, lastname:...
# 4  {firstname: Devika, middlename: None, lastname...
#
#                                               genres  \
# 0                        {id: 99, name: Documentary}
# 1  {id: 18, name: Drama}, {id: 10749, name: Romance}
# 2                              {id: 18, name: Drama}
# 3                              {id: 18, name: Drama}
# 4                              {id: 18, name: Drama}
#
#                                     spoken_languages  \
# 0  {english_name: English, iso_639_1: en, name: E...
# 1  {english_name: English, iso_639_1: en, name: E...
# 2  {english_name: English, iso_639_1: en, name: E...
# 3  {english_name: English, iso_639_1: en, name: E...
# 4  {english_name: Catalan, iso_639_1: ca, name: C...
#
#                                production_countries
# 0  {iso_3166_1: US, name: United States of America}
# 1            {iso_3166_1: GB, name: United Kingdom}
# 2            {iso_3166_1: GB, name: United Kingdom}
# 3            {iso_3166_1: GB, name: United Kingdom}
# 4                     {iso_3166_1: ES, name: Spain}

# %%
# Drop "byline.person" column
grouped_df = grouped_df.drop('byline.person', axis=1)
grouped_df.head()
# Out:
#                   title        original_title  budget original_language  \
# 0  Pamela, a Love Story  Pamela, A Love Story       0                en
# 1      In From the Side      In from the Side       0                en
# 2            After Love            After Love       0                en
# 3            After Love            After Love       0                en
# 4              Alcarràs              Alcarràs       0                ca
#
#                                  homepage  \
# 0  https://www.netflix.com/title/81590934
# 1       http://www.infromthesidemovie.com
# 2
# 3
# 4          https://www.alcarras-film.com/
#
#                                             overview  popularity  runtime  \
# 0  In her own words, through personal video and d...      17.091      113
# 1  Mark, a new and inexperienced rugby club membe...      14.059      134
# 2  Set in the port town of Dover in the South-Eas...      15.106       89
# 3  Set in the port town of Dover in the South-Eas...      15.106       89
# 4  In a small village in Catalonia, the peach far...      11.358      120
#
#    revenue release_date  ...  \
# 0        0   2023-01-30  ...
# 1        0   2022-09-16  ...
# 2        0   2021-06-04  ...
# 3        0   2021-06-04  ...
# 4        0   2022-04-29  ...
#
#                                        headline.main  headline.kicker  \
# 0   ‘Pamela, a Love Story’ Review: A Frank Look Back             None
# 1  ‘In From the Side’ Review: Love and Rugby Play...             None
# 2               ‘After Love’ Review: The Other Woman    Critic’s Pick
# 3  Review: Staying Together ‘After Love’ and Regr...             None
# 4                   ‘Alcarràs’ Review: Labor of Love             None
#
#   headline.content_kicker headline.print_headline headline.name headline.seo  \
# 0                    None    Pamela, a Love Story          None         None
# 1                    None        In From the Side          None         None
# 2                    None              After Love          None         None
# 3                    None              After Love          None         None
# 4                    None                Alcarràs          None         None
#
#   headline.sub     byline.original byline.organization                 Title
# 0         None      By Glenn Kenny                None  Pamela, a Love Story
# 1         None      By Kyle Turner                None      In From the Side
# 2         None  By Beatrice Loayza                None            After Love
# 3         None      By Glenn Kenny                None            After Love
# 4         None    By Devika Girish                None              Alcarràs
#
# [5 rows x 31 columns]

# %%
# Note: I should have de-duplicated already when I called out to IMDB. However the NYT Reviews could have still had duplicates
#grouped_df.shape

# Delete duplicate rows and reset index
grouped_df.drop_duplicates(inplace=True)
grouped_df.reset_index()
grouped_df.shape
# Out:
# (188, 31)

# %%
# Export data to CSV without the index
grouped_df.to_csv('output/output.csv', index=False)

# %%
# Using this block to test the substringing of Titles

# test = '‘The Attachment Diaries’ Review: Love, Sick	'
# test = 'Review: It’s All Mirth and Taxes in ‘Love & Taxes’'
# start_idx = test.index('‘')+1

# end_idx = test.index('’')

# while end_idx < start_idx:
#     print(end_idx, start_idx)
#     end_idx = test[end_idx+1 : len(test)].index('’') + end_idx + 1



# print(start_idx, end_idx)
# test = test[int(start_idx): int(end_idx)]
# test
# Out:
# 10 37
# 37 49
# 'Love & Taxes'
